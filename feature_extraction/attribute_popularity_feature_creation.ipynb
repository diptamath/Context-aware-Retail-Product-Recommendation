# %%
# ! pip install fastparquet --user
# ! pip install ordered-set
# ! pip install swifter --user

# %%
import pandas as pd
import swifter
import numpy as np
import gc
from tqdm import tqdm
from collections import defaultdict
from ordered_set import OrderedSet
from sklearn.decomposition import TruncatedSVD
from sklearn.preprocessing import MinMaxScaler, StandardScaler

# %%
train = pd.read_parquet("../data_phase1/train.parquet")
val = pd.read_parquet("../data_phase1/validation.parquet")

# %%
train = train.fillna(value={"context_type": "NA"})
val = val.fillna(value={"context_type": "NA"})

# %%
train.describe(include='O')
# Out:
#                                                  query_id  \
# count                                             3507990
# unique                                             584665
# top     cb21670cb4af4b9a8f1623e43a1d29cb60f1ae96cbbdb4...
# freq                                                    6
#
#                                                   user_id  \
# count                                             3507990
# unique                                             208393
# top     cc83479dd22e19ec45d08805a61b73d7f33a69feaf42be...
# freq                                                 4428
#
#                                                session_id  \
# count                                             3507990
# unique                                             317426
# top     f3de26eced2c81d1b0d6da40c11c9f987fe066b5a4f4fd...
# freq                                                  354
#
#                                                product_id  \
# count                                             3507990
# unique                                             408263
# top     55e1495c40504b4b15a358f95e2cbede34d011b287c32b...
# freq                                                 1728
#
#                                                 page_type  \
# count                                             3507990
# unique                                                  5
# top     06a7f8e972f61aeb0e06335699518079a444e4450ff766...
# freq                                              3105120
#
#                                        previous_page_type  \
# count                                             3507990
# unique                                                 23
# top     c9f34437ce0e536fefd11a34b9a411b541d2dabfec872a...
# freq                                              2053848
#
#                                           device_category  \
# count                                             3507990
# unique                                                  3
# top     bf2241c08d92d32a6782b4041a2c11ca58882ca88454b3...
# freq                                              1853280
#
#                                           device_platform  \
# count                                             3507990
# unique                                                  2
# top     702e4598004745673c0f6b50387bef9e1d5f503bd8c1c0...
# freq                                              1927596
#
#                                                 user_tier  \
# count                                             3507990
# unique                                                  6
# top     d74a5cebc23c56af60a5768c22d44b52f598629d4011fa...
# freq                                              2714292
#
#                                              user_country context_type  \
# count                                             3507990      3507990
# unique                                                196            5
# top     ea2f413bd8fda0b91a814a68aa520044b204796991a343...   product_id
# freq                                               520824      3105204
#
#                                             context_value
# count                                             3507990
# unique                                             189571
# top     d74a5cebc23c56af60a5768c22d44b52f598629d4011fa...
# freq                                               152514

# %%
val.describe(include='O')
# Out:
#                                                  query_id  \
# count                                              687192
# unique                                             114532
# top     748ea9fd8615989f0242efb43fe9383038db2816fa5b97...
# freq                                                    6
#
#                                                   user_id  \
# count                                              687192
# unique                                             114532
# top     9553c8a9c7b7d522f072a9414fd7722302649d87ba9b8e...
# freq                                                    6
#
#                                                session_id  \
# count                                              687192
# unique                                             114532
# top     e63518443b20d5373f6d9b3d2126ea8ecaeb98483aa0ae...
# freq                                                    6
#
#                                                product_id  \
# count                                              687192
# unique                                             218525
# top     fe13af44356050cdc93ad3d5e458e24c5077e5bf7a4c12...
# freq                                                  398
#
#                                                 page_type  \
# count                                              687192
# unique                                                  5
# top     06a7f8e972f61aeb0e06335699518079a444e4450ff766...
# freq                                               666960
#
#                                        previous_page_type  \
# count                                              687192
# unique                                                 22
# top     c9f34437ce0e536fefd11a34b9a411b541d2dabfec872a...
# freq                                               513864
#
#                                           device_category  \
# count                                              687192
# unique                                                  3
# top     bf2241c08d92d32a6782b4041a2c11ca58882ca88454b3...
# freq                                               411180
#
#                                           device_platform  \
# count                                              687192
# unique                                                  2
# top     702e4598004745673c0f6b50387bef9e1d5f503bd8c1c0...
# freq                                               423654
#
#                                                 user_tier  \
# count                                              687192
# unique                                                  6
# top     d74a5cebc23c56af60a5768c22d44b52f598629d4011fa...
# freq                                               605262
#
#                                              user_country context_type  \
# count                                              687192       687192
# unique                                                188            5
# top     ea2f413bd8fda0b91a814a68aa520044b204796991a343...   product_id
# freq                                               102696       666990
#
#                                             context_value
# count                                              687192
# unique                                              66955
# top     d74a5cebc23c56af60a5768c22d44b52f598629d4011fa...
# freq                                                15342

# %%
def reduce_mem_usage(df):
    start_mem = df.memory_usage().sum() / 1024 ** 2
    print('Memory usage of dataframe is {:.2f} MB'.format(start_mem))

    for col in df.columns:
        col_type = df[col].dtype

        if col_type != object:
            c_min = df[col].min()
            c_max = df[col].max()
            if str(col_type)[:3] == 'int':
                if c_min > np.iinfo(np.int8).min and c_max < np.iinfo(np.int8).max:
                    df[col] = df[col].astype(np.int8)
                elif c_min > np.iinfo(np.int16).min and c_max < np.iinfo(np.int16).max:
                    df[col] = df[col].astype(np.int16)
                elif c_min > np.iinfo(np.int32).min and c_max < np.iinfo(np.int32).max:
                    df[col] = df[col].astype(np.int32)
                elif c_min > np.iinfo(np.int64).min and c_max < np.iinfo(np.int64).max:
                    df[col] = df[col].astype(np.int64)
            else:
                if c_min > np.finfo(np.float16).min and c_max < np.finfo(np.float16).max:
                    df[col] = df[col].astype(np.float16)
                elif c_min > np.finfo(np.float32).min and c_max < np.finfo(np.float32).max:
                    df[col] = df[col].astype(np.float32)
                else:
                    df[col] = df[col].astype(np.float64)
        else:
            df[col] = df[col].astype('category')

    end_mem = df.memory_usage().sum() / 1024 ** 2
    print('Memory usage after optimization is: {:.2f} MB'.format(end_mem))
    print('Decreased by {:.1f}%'.format(100 * (start_mem - end_mem) / start_mem))

    return df

# %%
train = reduce_mem_usage(train)
val = reduce_mem_usage(val)
# Out:
# Memory usage of dataframe is 428.22 MB
# Memory usage after optimization is: 175.85 MB
# Decreased by 58.9%
# Memory usage of dataframe is 78.64 MB
# Memory usage after optimization is: 47.95 MB
# Decreased by 39.0%

# %%
gc.collect()
# Out:
# 22

# %%
train = train.sort_values(by='query_id').reset_index(drop=True)
val = val.sort_values(by='query_id').reset_index(drop=True)

# %%
train.head(10)
# Out:
#                                             query_id  \
# 0  0000437da0efd6e292f12a8a3bf7525de5bd05b5807a74...
# 1  0000437da0efd6e292f12a8a3bf7525de5bd05b5807a74...
# 2  0000437da0efd6e292f12a8a3bf7525de5bd05b5807a74...
# 3  0000437da0efd6e292f12a8a3bf7525de5bd05b5807a74...
# 4  0000437da0efd6e292f12a8a3bf7525de5bd05b5807a74...
# 5  0000437da0efd6e292f12a8a3bf7525de5bd05b5807a74...
# 6  00008bcf52759e7e70d533026da637b1cfeb0dc04a67ed...
# 7  00008bcf52759e7e70d533026da637b1cfeb0dc04a67ed...
# 8  00008bcf52759e7e70d533026da637b1cfeb0dc04a67ed...
# 9  00008bcf52759e7e70d533026da637b1cfeb0dc04a67ed...
#
#                                              user_id  \
# 0  ff2088c2fd3bf9cb8c2601252dd65a99201f59972820d3...
# 1  ff2088c2fd3bf9cb8c2601252dd65a99201f59972820d3...
# 2  ff2088c2fd3bf9cb8c2601252dd65a99201f59972820d3...
# 3  ff2088c2fd3bf9cb8c2601252dd65a99201f59972820d3...
# 4  ff2088c2fd3bf9cb8c2601252dd65a99201f59972820d3...
# 5  ff2088c2fd3bf9cb8c2601252dd65a99201f59972820d3...
# 6  968f154cc29e3fb1ed5f361ab23d9d8495cf47c5baefef...
# 7  968f154cc29e3fb1ed5f361ab23d9d8495cf47c5baefef...
# 8  968f154cc29e3fb1ed5f361ab23d9d8495cf47c5baefef...
# 9  968f154cc29e3fb1ed5f361ab23d9d8495cf47c5baefef...
#
#                                           session_id  \
# 0  37b65411191e2f12441edad785c6ae94741eceaffdcb80...
# 1  37b65411191e2f12441edad785c6ae94741eceaffdcb80...
# 2  37b65411191e2f12441edad785c6ae94741eceaffdcb80...
# 3  37b65411191e2f12441edad785c6ae94741eceaffdcb80...
# 4  37b65411191e2f12441edad785c6ae94741eceaffdcb80...
# 5  37b65411191e2f12441edad785c6ae94741eceaffdcb80...
# 6  f391f67a9d273be5a95460ce4756cdbc22430336a0b28d...
# 7  f391f67a9d273be5a95460ce4756cdbc22430336a0b28d...
# 8  f391f67a9d273be5a95460ce4756cdbc22430336a0b28d...
# 9  f391f67a9d273be5a95460ce4756cdbc22430336a0b28d...
#
#                                           product_id  \
# 0  1efd18182268101b62a1ea12a9cafbe05487f3abb92924...
# 1  62349c6eda0dc9fe8bb023213f03ebe93aefa5cbcdfecf...
# 2  aa0bbdfa55326b5c08d3472b1ee1d56fe13a82f63f46c8...
# 3  793301d78ea43b599acf05d350c8f9e485f5deaa417284...
# 4  9e03ca4af958bef1ce5d54e684a40ee7e3a9aa7e5010b6...
# 5  9e7f6f10b18f35ce924575f599465265e22fa9d75b13c9...
# 6  b08c37eac9adf04388a290b13105167b4a50911ac14e5c...
# 7  7b8c68e43264904ec9f74df2b9461fe7381aab12d0740e...
# 8  616636f3c60f43d24741d9eca7fe1c3c567825acc64348...
# 9  01f0a57f4fbc0e42e76960238fce01c28e29f23819ae04...
#
#                                            page_type  \
# 0  06a7f8e972f61aeb0e06335699518079a444e4450ff766...
# 1  06a7f8e972f61aeb0e06335699518079a444e4450ff766...
# 2  06a7f8e972f61aeb0e06335699518079a444e4450ff766...
# 3  06a7f8e972f61aeb0e06335699518079a444e4450ff766...
# 4  06a7f8e972f61aeb0e06335699518079a444e4450ff766...
# 5  06a7f8e972f61aeb0e06335699518079a444e4450ff766...
# 6  06a7f8e972f61aeb0e06335699518079a444e4450ff766...
# 7  06a7f8e972f61aeb0e06335699518079a444e4450ff766...
# 8  06a7f8e972f61aeb0e06335699518079a444e4450ff766...
# 9  06a7f8e972f61aeb0e06335699518079a444e4450ff766...
#
#                                   previous_page_type  \
# 0  d05d943023ee7c2091506a72ce25841e84f88a4233a11d...
# 1  d05d943023ee7c2091506a72ce25841e84f88a4233a11d...
# 2  d05d943023ee7c2091506a72ce25841e84f88a4233a11d...
# 3  d05d943023ee7c2091506a72ce25841e84f88a4233a11d...
# 4  d05d943023ee7c2091506a72ce25841e84f88a4233a11d...
# 5  d05d943023ee7c2091506a72ce25841e84f88a4233a11d...
# 6  c9f34437ce0e536fefd11a34b9a411b541d2dabfec872a...
# 7  c9f34437ce0e536fefd11a34b9a411b541d2dabfec872a...
# 8  c9f34437ce0e536fefd11a34b9a411b541d2dabfec872a...
# 9  c9f34437ce0e536fefd11a34b9a411b541d2dabfec872a...
#
#                                      device_category  \
# 0  bf2241c08d92d32a6782b4041a2c11ca58882ca88454b3...
# 1  bf2241c08d92d32a6782b4041a2c11ca58882ca88454b3...
# 2  bf2241c08d92d32a6782b4041a2c11ca58882ca88454b3...
# 3  bf2241c08d92d32a6782b4041a2c11ca58882ca88454b3...
# 4  bf2241c08d92d32a6782b4041a2c11ca58882ca88454b3...
# 5  bf2241c08d92d32a6782b4041a2c11ca58882ca88454b3...
# 6  bf2241c08d92d32a6782b4041a2c11ca58882ca88454b3...
# 7  bf2241c08d92d32a6782b4041a2c11ca58882ca88454b3...
# 8  bf2241c08d92d32a6782b4041a2c11ca58882ca88454b3...
# 9  bf2241c08d92d32a6782b4041a2c11ca58882ca88454b3...
#
#                                      device_platform  \
# 0  702e4598004745673c0f6b50387bef9e1d5f503bd8c1c0...
# 1  702e4598004745673c0f6b50387bef9e1d5f503bd8c1c0...
# 2  702e4598004745673c0f6b50387bef9e1d5f503bd8c1c0...
# 3  702e4598004745673c0f6b50387bef9e1d5f503bd8c1c0...
# 4  702e4598004745673c0f6b50387bef9e1d5f503bd8c1c0...
# 5  702e4598004745673c0f6b50387bef9e1d5f503bd8c1c0...
# 6  702e4598004745673c0f6b50387bef9e1d5f503bd8c1c0...
# 7  702e4598004745673c0f6b50387bef9e1d5f503bd8c1c0...
# 8  702e4598004745673c0f6b50387bef9e1d5f503bd8c1c0...
# 9  702e4598004745673c0f6b50387bef9e1d5f503bd8c1c0...
#
#                                            user_tier  \
# 0  d74a5cebc23c56af60a5768c22d44b52f598629d4011fa...
# 1  d74a5cebc23c56af60a5768c22d44b52f598629d4011fa...
# 2  d74a5cebc23c56af60a5768c22d44b52f598629d4011fa...
# 3  d74a5cebc23c56af60a5768c22d44b52f598629d4011fa...
# 4  d74a5cebc23c56af60a5768c22d44b52f598629d4011fa...
# 5  d74a5cebc23c56af60a5768c22d44b52f598629d4011fa...
# 6  d74a5cebc23c56af60a5768c22d44b52f598629d4011fa...
# 7  d74a5cebc23c56af60a5768c22d44b52f598629d4011fa...
# 8  d74a5cebc23c56af60a5768c22d44b52f598629d4011fa...
# 9  d74a5cebc23c56af60a5768c22d44b52f598629d4011fa...
#
#                                         user_country context_type  \
# 0  ea2f413bd8fda0b91a814a68aa520044b204796991a343...   product_id
# 1  ea2f413bd8fda0b91a814a68aa520044b204796991a343...   product_id
# 2  ea2f413bd8fda0b91a814a68aa520044b204796991a343...   product_id
# 3  ea2f413bd8fda0b91a814a68aa520044b204796991a343...   product_id
# 4  ea2f413bd8fda0b91a814a68aa520044b204796991a343...   product_id
# 5  ea2f413bd8fda0b91a814a68aa520044b204796991a343...   product_id
# 6  ea2f413bd8fda0b91a814a68aa520044b204796991a343...   product_id
# 7  ea2f413bd8fda0b91a814a68aa520044b204796991a343...   product_id
# 8  ea2f413bd8fda0b91a814a68aa520044b204796991a343...   product_id
# 9  ea2f413bd8fda0b91a814a68aa520044b204796991a343...   product_id
#
#                                        context_value  product_price  week  \
# 0  a6e9c2a832972484be2bd4378135743d1d00d651502c38...       0.000466     6
# 1  a6e9c2a832972484be2bd4378135743d1d00d651502c38...       0.001068     6
# 2  a6e9c2a832972484be2bd4378135743d1d00d651502c38...       0.001238     6
# 3  a6e9c2a832972484be2bd4378135743d1d00d651502c38...       0.000465     6
# 4  a6e9c2a832972484be2bd4378135743d1d00d651502c38...       0.000936     6
# 5  a6e9c2a832972484be2bd4378135743d1d00d651502c38...       0.001765     6
# 6  ca0bdabcd3a4eae25db6f95687cb307200e78892a6d774...       0.000804     7
# 7  ca0bdabcd3a4eae25db6f95687cb307200e78892a6d774...       0.000722     7
# 8  ca0bdabcd3a4eae25db6f95687cb307200e78892a6d774...       0.000916     7
# 9  ca0bdabcd3a4eae25db6f95687cb307200e78892a6d774...       0.000761     7
#
#    week_day  is_click
# 0         6         0
# 1         6         0
# 2         6         1
# 3         6         0
# 4         6         0
# 5         6         0
# 6         2         0
# 7         2         0
# 8         2         1
# 9         2         0

# %%
train.isnull().sum()
# Out:
# query_id              0
# user_id               0
# session_id            0
# product_id            0
# page_type             0
# previous_page_type    0
# device_category       0
# device_platform       0
# user_tier             0
# user_country          0
# context_type          0
# context_value         0
# product_price         0
# week                  0
# week_day              0
# is_click              0
# dtype: int64

# %%
data = pd.concat([train[list(set(train.columns)-set(['is_click']))], val], axis=0)
data = data.reset_index(drop=True)

# %%
all_products = data.product_id.apply(str).tolist()

# %%
unique_products = OrderedSet(all_products)

# %%
train_session_interactions = dict(train.groupby('session_id')['product_id'].apply(list))
val_session_interactions = dict(val.groupby('session_id')['product_id'].apply(list))

train_session_actions = dict(train.groupby('session_id')['is_click'].apply(list))
# val_session_actions = dict(val.groupby('session_id')['is_click'].apply(list))

# %%
train['days_elapsed'] = (train['week'].astype(int)-1)*7 + train['week_day'].astype(int)
val['days_elapsed'] = (val['week'].astype(int)-1)*7 + val['week_day'].astype(int)

# %%
val['days_elapsed'] = val['days_elapsed'] - train['days_elapsed'].min()
train['days_elapsed'] = train['days_elapsed'] - train['days_elapsed'].min()

# %%
val['days_elapsed'] = val['days_elapsed'] - train['days_elapsed'].min()
val.days_elapsed.unique()
# Out:
# array([43, 38, 41, 52, 53, 49, 11, 45, 46,  9, 48,  8, 20, 42, 34, 44, 40,
#        21, 39, 19, 14, 30, 47,  6, 33, 23, 17, 28,  5,  7, 13, 25])

# %%
gc.collect()
# Out:
# 88

# %%
attribute_data = pd.read_parquet("../data_phase1/attributes.parquet")

# %%
train_attr_data = train.merge(attribute_data, on='product_id', how='left')

# %%
is_click = train_attr_data.is_click.values
train_attr_data = train_attr_data.drop(['is_click'], 1)
train_attr_data['is_click'] = is_click

# %%
train_attr_data.head(2)
# Out:
#                                             query_id  \
# 0  0000437da0efd6e292f12a8a3bf7525de5bd05b5807a74...
# 1  0000437da0efd6e292f12a8a3bf7525de5bd05b5807a74...
#
#                                              user_id  \
# 0  ff2088c2fd3bf9cb8c2601252dd65a99201f59972820d3...
# 1  ff2088c2fd3bf9cb8c2601252dd65a99201f59972820d3...
#
#                                           session_id  \
# 0  37b65411191e2f12441edad785c6ae94741eceaffdcb80...
# 1  37b65411191e2f12441edad785c6ae94741eceaffdcb80...
#
#                                           product_id  \
# 0  1efd18182268101b62a1ea12a9cafbe05487f3abb92924...
# 1  62349c6eda0dc9fe8bb023213f03ebe93aefa5cbcdfecf...
#
#                                            page_type  \
# 0  06a7f8e972f61aeb0e06335699518079a444e4450ff766...
# 1  06a7f8e972f61aeb0e06335699518079a444e4450ff766...
#
#                                   previous_page_type  \
# 0  d05d943023ee7c2091506a72ce25841e84f88a4233a11d...
# 1  d05d943023ee7c2091506a72ce25841e84f88a4233a11d...
#
#                                      device_category  \
# 0  bf2241c08d92d32a6782b4041a2c11ca58882ca88454b3...
# 1  bf2241c08d92d32a6782b4041a2c11ca58882ca88454b3...
#
#                                      device_platform  \
# 0  702e4598004745673c0f6b50387bef9e1d5f503bd8c1c0...
# 1  702e4598004745673c0f6b50387bef9e1d5f503bd8c1c0...
#
#                                            user_tier  \
# 0  d74a5cebc23c56af60a5768c22d44b52f598629d4011fa...
# 1  d74a5cebc23c56af60a5768c22d44b52f598629d4011fa...
#
#                                         user_country  ...  \
# 0  ea2f413bd8fda0b91a814a68aa520044b204796991a343...  ...
# 1  ea2f413bd8fda0b91a814a68aa520044b204796991a343...  ...
#
#                                           collection  \
# 0  a3791e8d85c005b0d9d60d6d3b7e8edd2f256a5cc928d0...
# 1  4c8006c7e513057a9138641abc2a9e65f4b014a8045259...
#
#                                       category_id_l1  \
# 0  bb660069187af9e9238d10a742def09bf2bed60435b088...
# 1  abf367e49718254e068eee51a565fdcede2d741e4c7e33...
#
#                                       category_id_l2  \
# 0  663ca810e6cd391f1a8c24b0e39c4ac59f7e04c4759356...
# 1  61fe255948ec07c4eb25c70f7144b54beddd00466ad866...
#
#                                       category_id_l3  \
# 0  ca8c396e7422e324d4454a911e0319d07b85a4fb89b006...
# 1  ed7da2b533e9ccdf3dcaede4d2b8d170ffc32e2b922ee8...
#
#                                             brand_id  \
# 0  09e1d96d9e05b0bcab8bcba3943b899adb5177a8a4fe81...
# 1  2b225d501fd0ecd875cc3412eb5a14f96e98abc7b2f6bc...
#
#                                          season_year start_online_date  \
# 0  dc1194ba428d5cd4c49f8a769a6577ac1042162da38bc1...        573.041667
# 1  ef7d8d2e02aec8c328dafde95486f7181c37d07be3d167...        262.041667
#
#                                      material_values  \
# 0  4632872aedf88d5e81361e0389833dd1be3bcafc7e6b58...
# 1  f61ecea9b45f1590e57706b88207449bdd4cb703b917ad...
#
#                                     attribute_values is_click
# 0  ca8c396e7422e324d4454a911e0319d07b85a4fb89b006...        0
# 1  c22d2095ea26985f55d9ec999807dac2190b8be5a14397...        0
#
# [2 rows x 30 columns]

# %%
full_attribute_data = data[["query_id", "product_id", "user_id", "session_id"]].merge(attribute_data, on='product_id', how='left')

# %%
full_attribute_data.head(3)
# Out:
#                                             query_id  \
# 0  0000437da0efd6e292f12a8a3bf7525de5bd05b5807a74...
# 1  0000437da0efd6e292f12a8a3bf7525de5bd05b5807a74...
# 2  0000437da0efd6e292f12a8a3bf7525de5bd05b5807a74...
#
#                                           product_id  \
# 0  1efd18182268101b62a1ea12a9cafbe05487f3abb92924...
# 1  62349c6eda0dc9fe8bb023213f03ebe93aefa5cbcdfecf...
# 2  aa0bbdfa55326b5c08d3472b1ee1d56fe13a82f63f46c8...
#
#                                              user_id  \
# 0  ff2088c2fd3bf9cb8c2601252dd65a99201f59972820d3...
# 1  ff2088c2fd3bf9cb8c2601252dd65a99201f59972820d3...
# 2  ff2088c2fd3bf9cb8c2601252dd65a99201f59972820d3...
#
#                                           session_id  \
# 0  37b65411191e2f12441edad785c6ae94741eceaffdcb80...
# 1  37b65411191e2f12441edad785c6ae94741eceaffdcb80...
# 2  37b65411191e2f12441edad785c6ae94741eceaffdcb80...
#
#                                               gender  \
# 0  a8c9cca4c116691f1e331a5058e84f05e31696bc4f611c...
# 1  a8c9cca4c116691f1e331a5058e84f05e31696bc4f611c...
# 2  a8c9cca4c116691f1e331a5058e84f05e31696bc4f611c...
#
#                                          main_colour  \
# 0  8770603751ae3b965ab13bdd02c607985cd56be86d850b...
# 1  0f97dafafa5dc4bb18853ea00776dfcc52302f40411b50...
# 2  752e245892cce8aa87b8f41c583f95c7059cbaa4e9d61b...
#
#                                        second_colour  \
# 0  ca8c396e7422e324d4454a911e0319d07b85a4fb89b006...
# 1  ca8c396e7422e324d4454a911e0319d07b85a4fb89b006...
# 2  ca8c396e7422e324d4454a911e0319d07b85a4fb89b006...
#
#                                               season  \
# 0  9db35d237f5873f0410d3ca18c07430270086eb1e7838d...
# 1  9db35d237f5873f0410d3ca18c07430270086eb1e7838d...
# 2  9db35d237f5873f0410d3ca18c07430270086eb1e7838d...
#
#                                           collection  \
# 0  a3791e8d85c005b0d9d60d6d3b7e8edd2f256a5cc928d0...
# 1  4c8006c7e513057a9138641abc2a9e65f4b014a8045259...
# 2  4c8006c7e513057a9138641abc2a9e65f4b014a8045259...
#
#                                       category_id_l1  \
# 0  bb660069187af9e9238d10a742def09bf2bed60435b088...
# 1  abf367e49718254e068eee51a565fdcede2d741e4c7e33...
# 2  abf367e49718254e068eee51a565fdcede2d741e4c7e33...
#
#                                       category_id_l2  \
# 0  663ca810e6cd391f1a8c24b0e39c4ac59f7e04c4759356...
# 1  61fe255948ec07c4eb25c70f7144b54beddd00466ad866...
# 2  61fe255948ec07c4eb25c70f7144b54beddd00466ad866...
#
#                                       category_id_l3  \
# 0  ca8c396e7422e324d4454a911e0319d07b85a4fb89b006...
# 1  ed7da2b533e9ccdf3dcaede4d2b8d170ffc32e2b922ee8...
# 2  ed7da2b533e9ccdf3dcaede4d2b8d170ffc32e2b922ee8...
#
#                                             brand_id  \
# 0  09e1d96d9e05b0bcab8bcba3943b899adb5177a8a4fe81...
# 1  2b225d501fd0ecd875cc3412eb5a14f96e98abc7b2f6bc...
# 2  2b225d501fd0ecd875cc3412eb5a14f96e98abc7b2f6bc...
#
#                                          season_year  start_online_date  \
# 0  dc1194ba428d5cd4c49f8a769a6577ac1042162da38bc1...         573.041667
# 1  ef7d8d2e02aec8c328dafde95486f7181c37d07be3d167...         262.041667
# 2  ef7d8d2e02aec8c328dafde95486f7181c37d07be3d167...         226.041667
#
#                                      material_values  \
# 0  4632872aedf88d5e81361e0389833dd1be3bcafc7e6b58...
# 1  f61ecea9b45f1590e57706b88207449bdd4cb703b917ad...
# 2  2a9ca66cf16c629b4d0fb6d78e988a199db1490ef21d78...
#
#                                     attribute_values
# 0  ca8c396e7422e324d4454a911e0319d07b85a4fb89b006...
# 1  c22d2095ea26985f55d9ec999807dac2190b8be5a14397...
# 2  ca8c396e7422e324d4454a911e0319d07b85a4fb89b006...

# %% [markdown]
# # Brand

# %%
brand_impression_data = pd.DataFrame(full_attribute_data.groupby('brand_id').count()).reset_index()[["brand_id", "query_id"]]
brand_impression_data = brand_impression_data.rename(columns={'query_id': 'brand_impression_count'})
brand_impression_data.head()
# Out:
#                                             brand_id  brand_impression_count
# 0  001a11cdc499400927ae65d8fad803cff44c64be4035f5...                     658
# 1  003df714e5a9897245f0dcb93f1c04bc025cfa2be37bc7...                     118
# 2  0045d654875981a3692893e40fd72bba8bb054c8b63e84...                       2
# 3  004861d660ace63dfd4b549590fcb1a9e3e316a1a45e62...                      18
# 4  0049be50020812a0f5811102c38f97c1e24bee3622bd82...                      94

# %%
click_data = train_attr_data[train_attr_data['is_click']==1]

# %%
brand_click_data = pd.DataFrame(click_data.groupby('brand_id').count()).reset_index()[["brand_id", "query_id"]]
brand_click_data = brand_click_data.rename(columns={'query_id': 'brand_click_count'})
brand_click_data.head()
# Out:
#                                             brand_id  brand_click_count
# 0  001a11cdc499400927ae65d8fad803cff44c64be4035f5...                 95
# 1  003df714e5a9897245f0dcb93f1c04bc025cfa2be37bc7...                 14
# 2  004861d660ace63dfd4b549590fcb1a9e3e316a1a45e62...                  1
# 3  0049be50020812a0f5811102c38f97c1e24bee3622bd82...                 16
# 4  005c0db6f52c1f797f3e24459a1120d4815bd08c8aeddd...                  2

# %%
brand_data = brand_impression_data.merge(brand_click_data, on='brand_id', how='left')
brand_data = brand_data.fillna(0)
brand_data.head()
# Out:
#                                             brand_id  brand_impression_count  \
# 0  001a11cdc499400927ae65d8fad803cff44c64be4035f5...                     658
# 1  003df714e5a9897245f0dcb93f1c04bc025cfa2be37bc7...                     118
# 2  0045d654875981a3692893e40fd72bba8bb054c8b63e84...                       2
# 3  004861d660ace63dfd4b549590fcb1a9e3e316a1a45e62...                      18
# 4  0049be50020812a0f5811102c38f97c1e24bee3622bd82...                      94
#
#    brand_click_count
# 0               95.0
# 1               14.0
# 2                0.0
# 3                1.0
# 4               16.0

# %%
brand_data["brand_popularity_score"] = brand_data["brand_click_count"]/brand_data["brand_impression_count"]

# %%
brand_data.head()
# Out:
#                                             brand_id  brand_impression_count  \
# 0  001a11cdc499400927ae65d8fad803cff44c64be4035f5...                     658
# 1  003df714e5a9897245f0dcb93f1c04bc025cfa2be37bc7...                     118
# 2  0045d654875981a3692893e40fd72bba8bb054c8b63e84...                       2
# 3  004861d660ace63dfd4b549590fcb1a9e3e316a1a45e62...                      18
# 4  0049be50020812a0f5811102c38f97c1e24bee3622bd82...                      94
#
#    brand_click_count  brand_popularity_score
# 0               95.0                0.144377
# 1               14.0                0.118644
# 2                0.0                0.000000
# 3                1.0                0.055556
# 4               16.0                0.170213

# %%
# brand_data.to_csv("../preprocessed_data/brand_popularity_df.csv", index=False)

# %% [markdown]
# # Category L1

# %%
category_id_l1_impression_data = pd.DataFrame(full_attribute_data.groupby('category_id_l1').count()).reset_index()[["category_id_l1", "query_id"]]
category_id_l1_impression_data = category_id_l1_impression_data.rename(columns={'query_id': 'category_id_l1_impression_count'})
category_id_l1_impression_data.head()
# Out:
#                                       category_id_l1  \
# 0  01bdbf7ae5ca741c0db30ebea8c606042cbabac5e24217...
# 1  0248828a70652add64d469c493415bb53a03b4b103a59a...
# 2  02cf092784c2b661328d08172a50ad60ee5bbccd4d8d10...
# 3  09c394b9d5af703e13e57e80009cd0fb43b84416ba2e7b...
# 4  174386292851a161e3dd1792776ff0f50123b7d07d93d1...
#
#    category_id_l1_impression_count
# 0                            16442
# 1                             1233
# 2                            14997
# 3                             1164
# 4                              527

# %%
category_id_l1_click_data = pd.DataFrame(click_data.groupby('category_id_l1').count()).reset_index()[["category_id_l1", "query_id"]]
category_id_l1_click_data = category_id_l1_click_data.rename(columns={'query_id': 'category_id_l1_click_count'})
category_id_l1_click_data.head()
# Out:
#                                       category_id_l1  \
# 0  01bdbf7ae5ca741c0db30ebea8c606042cbabac5e24217...
# 1  0248828a70652add64d469c493415bb53a03b4b103a59a...
# 2  02cf092784c2b661328d08172a50ad60ee5bbccd4d8d10...
# 3  09c394b9d5af703e13e57e80009cd0fb43b84416ba2e7b...
# 4  174386292851a161e3dd1792776ff0f50123b7d07d93d1...
#
#    category_id_l1_click_count
# 0                        2164
# 1                         165
# 2                        2251
# 3                         186
# 4                          71

# %%
category_id_l1_data = category_id_l1_impression_data.merge(category_id_l1_click_data, on='category_id_l1', how='left')
category_id_l1_data = category_id_l1_data.fillna(0)
category_id_l1_data.head()
# Out:
#                                       category_id_l1  \
# 0  01bdbf7ae5ca741c0db30ebea8c606042cbabac5e24217...
# 1  0248828a70652add64d469c493415bb53a03b4b103a59a...
# 2  02cf092784c2b661328d08172a50ad60ee5bbccd4d8d10...
# 3  09c394b9d5af703e13e57e80009cd0fb43b84416ba2e7b...
# 4  174386292851a161e3dd1792776ff0f50123b7d07d93d1...
#
#    category_id_l1_impression_count  category_id_l1_click_count
# 0                            16442                        2164
# 1                             1233                         165
# 2                            14997                        2251
# 3                             1164                         186
# 4                              527                          71

# %%
category_id_l1_data["category_id_l1_popularity_score"] = category_id_l1_data["category_id_l1_click_count"]/category_id_l1_data["category_id_l1_impression_count"]
category_id_l1_data.head()
# Out:
#                                       category_id_l1  \
# 0  01bdbf7ae5ca741c0db30ebea8c606042cbabac5e24217...
# 1  0248828a70652add64d469c493415bb53a03b4b103a59a...
# 2  02cf092784c2b661328d08172a50ad60ee5bbccd4d8d10...
# 3  09c394b9d5af703e13e57e80009cd0fb43b84416ba2e7b...
# 4  174386292851a161e3dd1792776ff0f50123b7d07d93d1...
#
#    category_id_l1_impression_count  category_id_l1_click_count  \
# 0                            16442                        2164
# 1                             1233                         165
# 2                            14997                        2251
# 3                             1164                         186
# 4                              527                          71
#
#    category_id_l1_popularity_score
# 0                         0.131614
# 1                         0.133820
# 2                         0.150097
# 3                         0.159794
# 4                         0.134725

# %%
# category_id_l1_data.to_csv("../preprocessed_data/category_id_l1_popularity_df.csv", index=False)

# %% [markdown]
# # Category L2

# %%
category_id_l2_impression_data = pd.DataFrame(full_attribute_data.groupby('category_id_l2').count()).reset_index()[["category_id_l2", "query_id"]]
category_id_l2_impression_data = category_id_l2_impression_data.rename(columns={'query_id': 'category_id_l2_impression_count'})
category_id_l2_impression_data.head()
# Out:
#                                       category_id_l2  \
# 0  000651f17486a862c075e5a2a0131a750abeea6db55ad3...
# 1  000bdb044ab0dc94653d0b77046c8f6d4d22f2ac342773...
# 2  009a4ca993df6dd9828587d23ba38be14f1f6b7172516d...
# 3  00ebf4a9f1cbba7fe21b3690246defdc438326eebb10d3...
# 4  017f77b88550e40b287c7097544fc432ab8227595ed1ce...
#
#    category_id_l2_impression_count
# 0                             1695
# 1                              563
# 2                             3059
# 3                             2300
# 4                               12

# %%
category_id_l2_click_data = pd.DataFrame(click_data.groupby('category_id_l2').count()).reset_index()[["category_id_l2", "query_id"]]
category_id_l2_click_data = category_id_l2_click_data.rename(columns={'query_id': 'category_id_l2_click_count'})
category_id_l2_click_data.head()
# Out:
#                                       category_id_l2  \
# 0  000651f17486a862c075e5a2a0131a750abeea6db55ad3...
# 1  000bdb044ab0dc94653d0b77046c8f6d4d22f2ac342773...
# 2  009a4ca993df6dd9828587d23ba38be14f1f6b7172516d...
# 3  00ebf4a9f1cbba7fe21b3690246defdc438326eebb10d3...
# 4  017f77b88550e40b287c7097544fc432ab8227595ed1ce...
#
#    category_id_l2_click_count
# 0                         229
# 1                          81
# 2                         444
# 3                         309
# 4                           1

# %%
category_id_l2_data = category_id_l2_impression_data.merge(category_id_l2_click_data, on='category_id_l2', how='left')
category_id_l2_data = category_id_l2_data.fillna(0)
category_id_l2_data.head()
# Out:
#                                       category_id_l2  \
# 0  000651f17486a862c075e5a2a0131a750abeea6db55ad3...
# 1  000bdb044ab0dc94653d0b77046c8f6d4d22f2ac342773...
# 2  009a4ca993df6dd9828587d23ba38be14f1f6b7172516d...
# 3  00ebf4a9f1cbba7fe21b3690246defdc438326eebb10d3...
# 4  017f77b88550e40b287c7097544fc432ab8227595ed1ce...
#
#    category_id_l2_impression_count  category_id_l2_click_count
# 0                             1695                       229.0
# 1                              563                        81.0
# 2                             3059                       444.0
# 3                             2300                       309.0
# 4                               12                         1.0

# %%
category_id_l2_data["category_id_l2_popularity_score"] = category_id_l2_data["category_id_l2_click_count"]/category_id_l2_data["category_id_l2_impression_count"]
category_id_l2_data.head()
# Out:
#                                       category_id_l2  \
# 0  000651f17486a862c075e5a2a0131a750abeea6db55ad3...
# 1  000bdb044ab0dc94653d0b77046c8f6d4d22f2ac342773...
# 2  009a4ca993df6dd9828587d23ba38be14f1f6b7172516d...
# 3  00ebf4a9f1cbba7fe21b3690246defdc438326eebb10d3...
# 4  017f77b88550e40b287c7097544fc432ab8227595ed1ce...
#
#    category_id_l2_impression_count  category_id_l2_click_count  \
# 0                             1695                       229.0
# 1                              563                        81.0
# 2                             3059                       444.0
# 3                             2300                       309.0
# 4                               12                         1.0
#
#    category_id_l2_popularity_score
# 0                         0.135103
# 1                         0.143872
# 2                         0.145145
# 3                         0.134348
# 4                         0.083333

# %%
# category_id_l2_data.to_csv("../preprocessed_data/category_id_l2_popularity_df.csv", index=False)

# %% [markdown]
# # Main Colour

# %%
main_colour_impression_data = pd.DataFrame(full_attribute_data.groupby('main_colour').count()).reset_index()[["main_colour", "query_id"]]
main_colour_impression_data = main_colour_impression_data.rename(columns={'query_id': 'main_colour_impression_count'})
main_colour_impression_data.head()
# Out:
#                                          main_colour  \
# 0  0078d3ef1479189e5a922b27e2540a7bb1d10eb9ec0581...
# 1  0a89539f0dde241e4171b2daa052a1ff94c13b85532e0e...
# 2  0f97dafafa5dc4bb18853ea00776dfcc52302f40411b50...
# 3  4737cd35940c2338e96c18a25aeb6848d46f0da795bce8...
# 4  58d4862ee98f76d3e192f544dbe081472c716b66cf7928...
#
#    main_colour_impression_count
# 0                         64150
# 1                         24456
# 2                        429952
# 3                         17550
# 4                        266552

# %%
main_colour_click_data = pd.DataFrame(click_data.groupby('main_colour').count()).reset_index()[["main_colour", "query_id"]]
main_colour_click_data = main_colour_click_data.rename(columns={'query_id': 'main_colour_click_count'})
main_colour_click_data.head()
# Out:
#                                          main_colour  main_colour_click_count
# 0  0078d3ef1479189e5a922b27e2540a7bb1d10eb9ec0581...                     9005
# 1  0a89539f0dde241e4171b2daa052a1ff94c13b85532e0e...                     3617
# 2  0f97dafafa5dc4bb18853ea00776dfcc52302f40411b50...                    62540
# 3  4737cd35940c2338e96c18a25aeb6848d46f0da795bce8...                     2447
# 4  58d4862ee98f76d3e192f544dbe081472c716b66cf7928...                    38752

# %%
main_colour_data = main_colour_impression_data.merge(main_colour_click_data, on='main_colour', how='left')
main_colour_data = main_colour_data.fillna(0)
main_colour_data.head()
# Out:
#                                          main_colour  \
# 0  0078d3ef1479189e5a922b27e2540a7bb1d10eb9ec0581...
# 1  0a89539f0dde241e4171b2daa052a1ff94c13b85532e0e...
# 2  0f97dafafa5dc4bb18853ea00776dfcc52302f40411b50...
# 3  4737cd35940c2338e96c18a25aeb6848d46f0da795bce8...
# 4  58d4862ee98f76d3e192f544dbe081472c716b66cf7928...
#
#    main_colour_impression_count  main_colour_click_count
# 0                         64150                     9005
# 1                         24456                     3617
# 2                        429952                    62540
# 3                         17550                     2447
# 4                        266552                    38752

# %%
main_colour_data["main_colour_popularity_score"] = main_colour_data["main_colour_click_count"]/main_colour_data["main_colour_impression_count"]
main_colour_data.head()
# Out:
#                                          main_colour  \
# 0  0078d3ef1479189e5a922b27e2540a7bb1d10eb9ec0581...
# 1  0a89539f0dde241e4171b2daa052a1ff94c13b85532e0e...
# 2  0f97dafafa5dc4bb18853ea00776dfcc52302f40411b50...
# 3  4737cd35940c2338e96c18a25aeb6848d46f0da795bce8...
# 4  58d4862ee98f76d3e192f544dbe081472c716b66cf7928...
#
#    main_colour_impression_count  main_colour_click_count  \
# 0                         64150                     9005
# 1                         24456                     3617
# 2                        429952                    62540
# 3                         17550                     2447
# 4                        266552                    38752
#
#    main_colour_popularity_score
# 0                      0.140374
# 1                      0.147898
# 2                      0.145458
# 3                      0.139430
# 4                      0.145383

# %%
# main_colour_data.to_csv("../preprocessed_data/main_colour_popularity_df.csv", index=False)

# %% [markdown]
# # Second Colour

# %%
second_colour_impression_data = pd.DataFrame(full_attribute_data.groupby('second_colour').count()).reset_index()[["second_colour", "query_id"]]
second_colour_impression_data = second_colour_impression_data.rename(columns={'query_id': 'second_colour_impression_count'})
second_colour_impression_data.head()
# Out:
#                                        second_colour  \
# 0  0078d3ef1479189e5a922b27e2540a7bb1d10eb9ec0581...
# 1  0a89539f0dde241e4171b2daa052a1ff94c13b85532e0e...
# 2  0f97dafafa5dc4bb18853ea00776dfcc52302f40411b50...
# 3  3cf10b7e1460bf9131817644937b860b13ec960b82758b...
# 4  4737cd35940c2338e96c18a25aeb6848d46f0da795bce8...
#
#    second_colour_impression_count
# 0                           35145
# 1                           12633
# 2                           54373
# 3                             415
# 4                           25671

# %%
second_colour_click_data = pd.DataFrame(click_data.groupby('second_colour').count()).reset_index()[["second_colour", "query_id"]]
second_colour_click_data = second_colour_click_data.rename(columns={'query_id': 'second_colour_click_count'})
second_colour_click_data.head()
# Out:
#                                        second_colour  \
# 0  0078d3ef1479189e5a922b27e2540a7bb1d10eb9ec0581...
# 1  0a89539f0dde241e4171b2daa052a1ff94c13b85532e0e...
# 2  0f97dafafa5dc4bb18853ea00776dfcc52302f40411b50...
# 3  3cf10b7e1460bf9131817644937b860b13ec960b82758b...
# 4  4737cd35940c2338e96c18a25aeb6848d46f0da795bce8...
#
#    second_colour_click_count
# 0                       4744
# 1                       1822
# 2                       7775
# 3                         49
# 4                       3698

# %%
second_colour_data = second_colour_impression_data.merge(second_colour_click_data, on='second_colour', how='left')
second_colour_data = second_colour_data.fillna(0)
second_colour_data.head()
# Out:
#                                        second_colour  \
# 0  0078d3ef1479189e5a922b27e2540a7bb1d10eb9ec0581...
# 1  0a89539f0dde241e4171b2daa052a1ff94c13b85532e0e...
# 2  0f97dafafa5dc4bb18853ea00776dfcc52302f40411b50...
# 3  3cf10b7e1460bf9131817644937b860b13ec960b82758b...
# 4  4737cd35940c2338e96c18a25aeb6848d46f0da795bce8...
#
#    second_colour_impression_count  second_colour_click_count
# 0                           35145                     4744.0
# 1                           12633                     1822.0
# 2                           54373                     7775.0
# 3                             415                       49.0
# 4                           25671                     3698.0

# %%
second_colour_data["second_colour_popularity_score"] = second_colour_data["second_colour_click_count"]/second_colour_data["second_colour_impression_count"]
second_colour_data.head()
# Out:
#                                        second_colour  \
# 0  0078d3ef1479189e5a922b27e2540a7bb1d10eb9ec0581...
# 1  0a89539f0dde241e4171b2daa052a1ff94c13b85532e0e...
# 2  0f97dafafa5dc4bb18853ea00776dfcc52302f40411b50...
# 3  3cf10b7e1460bf9131817644937b860b13ec960b82758b...
# 4  4737cd35940c2338e96c18a25aeb6848d46f0da795bce8...
#
#    second_colour_impression_count  second_colour_click_count  \
# 0                           35145                     4744.0
# 1                           12633                     1822.0
# 2                           54373                     7775.0
# 3                             415                       49.0
# 4                           25671                     3698.0
#
#    second_colour_popularity_score
# 0                        0.134984
# 1                        0.144225
# 2                        0.142994
# 3                        0.118072
# 4                        0.144054

# %%
# second_colour_data.to_csv("../preprocessed_data/second_colour_popularity_df.csv", index=False)

# %% [markdown]
# # Collection

# %%
collection_impression_data = pd.DataFrame(full_attribute_data.groupby('collection').count()).reset_index()[["collection", "query_id"]]
collection_impression_data = collection_impression_data.rename(columns={'query_id': 'collection_impression_count'})
collection_impression_data.head()
# Out:
#                                           collection  \
# 0  3e5d88c58066b4182e2eb9e0e2206aaba3a46b193e4788...
# 1  4c8006c7e513057a9138641abc2a9e65f4b014a8045259...
# 2  6611f47aa127beb2b2fcb372eab3945274b5e742af07c2...
# 3  a3791e8d85c005b0d9d60d6d3b7e8edd2f256a5cc928d0...
# 4  b5beb2ed60981746e0b908797b3d3abb8491de15ff5575...
#
#    collection_impression_count
# 0                        18102
# 1                      2070924
# 2                        31066
# 3                      1574209
# 4                       425039

# %%
collection_click_data = pd.DataFrame(click_data.groupby('collection').count()).reset_index()[["collection", "query_id"]]
collection_click_data = collection_click_data.rename(columns={'query_id': 'collection_click_count'})
collection_click_data.head()
# Out:
#                                           collection  collection_click_count
# 0  3e5d88c58066b4182e2eb9e0e2206aaba3a46b193e4788...                    2517
# 1  4c8006c7e513057a9138641abc2a9e65f4b014a8045259...                  296997
# 2  6611f47aa127beb2b2fcb372eab3945274b5e742af07c2...                    4599
# 3  a3791e8d85c005b0d9d60d6d3b7e8edd2f256a5cc928d0...                  227540
# 4  b5beb2ed60981746e0b908797b3d3abb8491de15ff5575...                   60073

# %%
collection_data = collection_impression_data.merge(collection_click_data, on='collection', how='left')
collection_data = collection_data.fillna(0)
collection_data.head()
# Out:
#                                           collection  \
# 0  3e5d88c58066b4182e2eb9e0e2206aaba3a46b193e4788...
# 1  4c8006c7e513057a9138641abc2a9e65f4b014a8045259...
# 2  6611f47aa127beb2b2fcb372eab3945274b5e742af07c2...
# 3  a3791e8d85c005b0d9d60d6d3b7e8edd2f256a5cc928d0...
# 4  b5beb2ed60981746e0b908797b3d3abb8491de15ff5575...
#
#    collection_impression_count  collection_click_count
# 0                        18102                    2517
# 1                      2070924                  296997
# 2                        31066                    4599
# 3                      1574209                  227540
# 4                       425039                   60073

# %%
collection_data["collection_popularity_score"] = collection_data["collection_click_count"]/collection_data["collection_impression_count"]
collection_data.head()
# Out:
#                                           collection  \
# 0  3e5d88c58066b4182e2eb9e0e2206aaba3a46b193e4788...
# 1  4c8006c7e513057a9138641abc2a9e65f4b014a8045259...
# 2  6611f47aa127beb2b2fcb372eab3945274b5e742af07c2...
# 3  a3791e8d85c005b0d9d60d6d3b7e8edd2f256a5cc928d0...
# 4  b5beb2ed60981746e0b908797b3d3abb8491de15ff5575...
#
#    collection_impression_count  collection_click_count  \
# 0                        18102                    2517
# 1                      2070924                  296997
# 2                        31066                    4599
# 3                      1574209                  227540
# 4                       425039                   60073
#
#    collection_popularity_score
# 0                     0.139045
# 1                     0.143413
# 2                     0.148040
# 3                     0.144542
# 4                     0.141335

# %%
# collection_data.to_csv("../preprocessed_data/collection_popularity_df.csv", index=False)
