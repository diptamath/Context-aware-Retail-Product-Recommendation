# %%
# ! pip install fastparquet --user
# ! pip install ordered-set

# %%
import pandas as pd
import numpy as np
import swifter
import gc
from tqdm import tqdm
from collections import defaultdict
from ordered_set import OrderedSet
from sklearn.decomposition import TruncatedSVD
from sklearn.preprocessing import MinMaxScaler, StandardScaler

# %%
train = pd.read_parquet("../data_phase1/train.parquet")
val = pd.read_parquet("../data_phase1/validation.parquet")
test = pd.read_parquet("../data_phase2/test.parquet")

# %%
train = train.fillna(value={"context_type": "NA"})
val = val.fillna(value={"context_type": "NA"})
test = test.fillna(value={"context_type": "NA"})

# %%
train.describe(include='O')
# Out:
#                                                  query_id  \
# count                                             3507990
# unique                                             584665
# top     af28f0072befaa1d50de30777aabe3db69a11bbafcb420...
# freq                                                    6
#
#                                                   user_id  \
# count                                             3507990
# unique                                             208393
# top     cc83479dd22e19ec45d08805a61b73d7f33a69feaf42be...
# freq                                                 4428
#
#                                                session_id  \
# count                                             3507990
# unique                                             317426
# top     f3de26eced2c81d1b0d6da40c11c9f987fe066b5a4f4fd...
# freq                                                  354
#
#                                                product_id  \
# count                                             3507990
# unique                                             408263
# top     55e1495c40504b4b15a358f95e2cbede34d011b287c32b...
# freq                                                 1728
#
#                                                 page_type  \
# count                                             3507990
# unique                                                  5
# top     06a7f8e972f61aeb0e06335699518079a444e4450ff766...
# freq                                              3105120
#
#                                        previous_page_type  \
# count                                             3507990
# unique                                                 23
# top     c9f34437ce0e536fefd11a34b9a411b541d2dabfec872a...
# freq                                              2053848
#
#                                           device_category  \
# count                                             3507990
# unique                                                  3
# top     bf2241c08d92d32a6782b4041a2c11ca58882ca88454b3...
# freq                                              1853280
#
#                                           device_platform  \
# count                                             3507990
# unique                                                  2
# top     702e4598004745673c0f6b50387bef9e1d5f503bd8c1c0...
# freq                                              1927596
#
#                                                 user_tier  \
# count                                             3507990
# unique                                                  6
# top     d74a5cebc23c56af60a5768c22d44b52f598629d4011fa...
# freq                                              2714292
#
#                                              user_country context_type  \
# count                                             3507990      3507990
# unique                                                196            5
# top     ea2f413bd8fda0b91a814a68aa520044b204796991a343...   product_id
# freq                                               520824      3105204
#
#                                             context_value
# count                                             3507990
# unique                                             189571
# top     d74a5cebc23c56af60a5768c22d44b52f598629d4011fa...
# freq                                               152514

# %%
val.describe(include='O')
# Out:
#                                                  query_id  \
# count                                              687192
# unique                                             114532
# top     cbfc2f4c5b6609e80a9f54207f61cd5a531ee03efe59a7...
# freq                                                    6
#
#                                                   user_id  \
# count                                              687192
# unique                                             114532
# top     4c0ca183b5aabdbf3f7717aa7a24f85d15a882e00034e6...
# freq                                                    6
#
#                                                session_id  \
# count                                              687192
# unique                                             114532
# top     c262fb07a4aa1d479f63b1ba48c4c6618aa737b74b9ce0...
# freq                                                    6
#
#                                                product_id  \
# count                                              687192
# unique                                             218525
# top     fe13af44356050cdc93ad3d5e458e24c5077e5bf7a4c12...
# freq                                                  398
#
#                                                 page_type  \
# count                                              687192
# unique                                                  5
# top     06a7f8e972f61aeb0e06335699518079a444e4450ff766...
# freq                                               666960
#
#                                        previous_page_type  \
# count                                              687192
# unique                                                 22
# top     c9f34437ce0e536fefd11a34b9a411b541d2dabfec872a...
# freq                                               513864
#
#                                           device_category  \
# count                                              687192
# unique                                                  3
# top     bf2241c08d92d32a6782b4041a2c11ca58882ca88454b3...
# freq                                               411180
#
#                                           device_platform  \
# count                                              687192
# unique                                                  2
# top     702e4598004745673c0f6b50387bef9e1d5f503bd8c1c0...
# freq                                               423654
#
#                                                 user_tier  \
# count                                              687192
# unique                                                  6
# top     d74a5cebc23c56af60a5768c22d44b52f598629d4011fa...
# freq                                               605262
#
#                                              user_country context_type  \
# count                                              687192       687192
# unique                                                188            5
# top     ea2f413bd8fda0b91a814a68aa520044b204796991a343...   product_id
# freq                                               102696       666990
#
#                                             context_value
# count                                              687192
# unique                                              66955
# top     d74a5cebc23c56af60a5768c22d44b52f598629d4011fa...
# freq                                                15342

# %%
def reduce_mem_usage(df):
    start_mem = df.memory_usage().sum() / 1024 ** 2
    print('Memory usage of dataframe is {:.2f} MB'.format(start_mem))

    for col in df.columns:
        col_type = df[col].dtype

        if col_type != object:
            c_min = df[col].min()
            c_max = df[col].max()
            if str(col_type)[:3] == 'int':
                if c_min > np.iinfo(np.int8).min and c_max < np.iinfo(np.int8).max:
                    df[col] = df[col].astype(np.int8)
                elif c_min > np.iinfo(np.int16).min and c_max < np.iinfo(np.int16).max:
                    df[col] = df[col].astype(np.int16)
                elif c_min > np.iinfo(np.int32).min and c_max < np.iinfo(np.int32).max:
                    df[col] = df[col].astype(np.int32)
                elif c_min > np.iinfo(np.int64).min and c_max < np.iinfo(np.int64).max:
                    df[col] = df[col].astype(np.int64)
            else:
                if c_min > np.finfo(np.float16).min and c_max < np.finfo(np.float16).max:
                    df[col] = df[col].astype(np.float16)
                elif c_min > np.finfo(np.float32).min and c_max < np.finfo(np.float32).max:
                    df[col] = df[col].astype(np.float32)
                else:
                    df[col] = df[col].astype(np.float64)
        else:
            df[col] = df[col].astype('category')

    end_mem = df.memory_usage().sum() / 1024 ** 2
    print('Memory usage after optimization is: {:.2f} MB'.format(end_mem))
    print('Decreased by {:.1f}%'.format(100 * (start_mem - end_mem) / start_mem))

    return df

# %%
train = reduce_mem_usage(train)
val = reduce_mem_usage(val)
test = reduce_mem_usage(test)
# Out:
# Memory usage of dataframe is 428.22 MB
# Memory usage after optimization is: 175.85 MB
# Decreased by 58.9%
# Memory usage of dataframe is 78.64 MB
# Memory usage after optimization is: 47.95 MB
# Decreased by 39.0%
# Memory usage of dataframe is 78.64 MB
# Memory usage after optimization is: 47.88 MB
# Decreased by 39.1%

# %%
gc.collect()
# Out:
# 22

# %%
train = train.sort_values(by='query_id').reset_index(drop=True)
val = val.sort_values(by='query_id').reset_index(drop=True)
test = test.sort_values(by='query_id').reset_index(drop=True)

# %%
train.head(10)
# Out:
#                                             query_id  \
# 0  0000437da0efd6e292f12a8a3bf7525de5bd05b5807a74...
# 1  0000437da0efd6e292f12a8a3bf7525de5bd05b5807a74...
# 2  0000437da0efd6e292f12a8a3bf7525de5bd05b5807a74...
# 3  0000437da0efd6e292f12a8a3bf7525de5bd05b5807a74...
# 4  0000437da0efd6e292f12a8a3bf7525de5bd05b5807a74...
# 5  0000437da0efd6e292f12a8a3bf7525de5bd05b5807a74...
# 6  00008bcf52759e7e70d533026da637b1cfeb0dc04a67ed...
# 7  00008bcf52759e7e70d533026da637b1cfeb0dc04a67ed...
# 8  00008bcf52759e7e70d533026da637b1cfeb0dc04a67ed...
# 9  00008bcf52759e7e70d533026da637b1cfeb0dc04a67ed...
#
#                                              user_id  \
# 0  ff2088c2fd3bf9cb8c2601252dd65a99201f59972820d3...
# 1  ff2088c2fd3bf9cb8c2601252dd65a99201f59972820d3...
# 2  ff2088c2fd3bf9cb8c2601252dd65a99201f59972820d3...
# 3  ff2088c2fd3bf9cb8c2601252dd65a99201f59972820d3...
# 4  ff2088c2fd3bf9cb8c2601252dd65a99201f59972820d3...
# 5  ff2088c2fd3bf9cb8c2601252dd65a99201f59972820d3...
# 6  968f154cc29e3fb1ed5f361ab23d9d8495cf47c5baefef...
# 7  968f154cc29e3fb1ed5f361ab23d9d8495cf47c5baefef...
# 8  968f154cc29e3fb1ed5f361ab23d9d8495cf47c5baefef...
# 9  968f154cc29e3fb1ed5f361ab23d9d8495cf47c5baefef...
#
#                                           session_id  \
# 0  37b65411191e2f12441edad785c6ae94741eceaffdcb80...
# 1  37b65411191e2f12441edad785c6ae94741eceaffdcb80...
# 2  37b65411191e2f12441edad785c6ae94741eceaffdcb80...
# 3  37b65411191e2f12441edad785c6ae94741eceaffdcb80...
# 4  37b65411191e2f12441edad785c6ae94741eceaffdcb80...
# 5  37b65411191e2f12441edad785c6ae94741eceaffdcb80...
# 6  f391f67a9d273be5a95460ce4756cdbc22430336a0b28d...
# 7  f391f67a9d273be5a95460ce4756cdbc22430336a0b28d...
# 8  f391f67a9d273be5a95460ce4756cdbc22430336a0b28d...
# 9  f391f67a9d273be5a95460ce4756cdbc22430336a0b28d...
#
#                                           product_id  \
# 0  1efd18182268101b62a1ea12a9cafbe05487f3abb92924...
# 1  62349c6eda0dc9fe8bb023213f03ebe93aefa5cbcdfecf...
# 2  aa0bbdfa55326b5c08d3472b1ee1d56fe13a82f63f46c8...
# 3  793301d78ea43b599acf05d350c8f9e485f5deaa417284...
# 4  9e03ca4af958bef1ce5d54e684a40ee7e3a9aa7e5010b6...
# 5  9e7f6f10b18f35ce924575f599465265e22fa9d75b13c9...
# 6  b08c37eac9adf04388a290b13105167b4a50911ac14e5c...
# 7  7b8c68e43264904ec9f74df2b9461fe7381aab12d0740e...
# 8  616636f3c60f43d24741d9eca7fe1c3c567825acc64348...
# 9  01f0a57f4fbc0e42e76960238fce01c28e29f23819ae04...
#
#                                            page_type  \
# 0  06a7f8e972f61aeb0e06335699518079a444e4450ff766...
# 1  06a7f8e972f61aeb0e06335699518079a444e4450ff766...
# 2  06a7f8e972f61aeb0e06335699518079a444e4450ff766...
# 3  06a7f8e972f61aeb0e06335699518079a444e4450ff766...
# 4  06a7f8e972f61aeb0e06335699518079a444e4450ff766...
# 5  06a7f8e972f61aeb0e06335699518079a444e4450ff766...
# 6  06a7f8e972f61aeb0e06335699518079a444e4450ff766...
# 7  06a7f8e972f61aeb0e06335699518079a444e4450ff766...
# 8  06a7f8e972f61aeb0e06335699518079a444e4450ff766...
# 9  06a7f8e972f61aeb0e06335699518079a444e4450ff766...
#
#                                   previous_page_type  \
# 0  d05d943023ee7c2091506a72ce25841e84f88a4233a11d...
# 1  d05d943023ee7c2091506a72ce25841e84f88a4233a11d...
# 2  d05d943023ee7c2091506a72ce25841e84f88a4233a11d...
# 3  d05d943023ee7c2091506a72ce25841e84f88a4233a11d...
# 4  d05d943023ee7c2091506a72ce25841e84f88a4233a11d...
# 5  d05d943023ee7c2091506a72ce25841e84f88a4233a11d...
# 6  c9f34437ce0e536fefd11a34b9a411b541d2dabfec872a...
# 7  c9f34437ce0e536fefd11a34b9a411b541d2dabfec872a...
# 8  c9f34437ce0e536fefd11a34b9a411b541d2dabfec872a...
# 9  c9f34437ce0e536fefd11a34b9a411b541d2dabfec872a...
#
#                                      device_category  \
# 0  bf2241c08d92d32a6782b4041a2c11ca58882ca88454b3...
# 1  bf2241c08d92d32a6782b4041a2c11ca58882ca88454b3...
# 2  bf2241c08d92d32a6782b4041a2c11ca58882ca88454b3...
# 3  bf2241c08d92d32a6782b4041a2c11ca58882ca88454b3...
# 4  bf2241c08d92d32a6782b4041a2c11ca58882ca88454b3...
# 5  bf2241c08d92d32a6782b4041a2c11ca58882ca88454b3...
# 6  bf2241c08d92d32a6782b4041a2c11ca58882ca88454b3...
# 7  bf2241c08d92d32a6782b4041a2c11ca58882ca88454b3...
# 8  bf2241c08d92d32a6782b4041a2c11ca58882ca88454b3...
# 9  bf2241c08d92d32a6782b4041a2c11ca58882ca88454b3...
#
#                                      device_platform  \
# 0  702e4598004745673c0f6b50387bef9e1d5f503bd8c1c0...
# 1  702e4598004745673c0f6b50387bef9e1d5f503bd8c1c0...
# 2  702e4598004745673c0f6b50387bef9e1d5f503bd8c1c0...
# 3  702e4598004745673c0f6b50387bef9e1d5f503bd8c1c0...
# 4  702e4598004745673c0f6b50387bef9e1d5f503bd8c1c0...
# 5  702e4598004745673c0f6b50387bef9e1d5f503bd8c1c0...
# 6  702e4598004745673c0f6b50387bef9e1d5f503bd8c1c0...
# 7  702e4598004745673c0f6b50387bef9e1d5f503bd8c1c0...
# 8  702e4598004745673c0f6b50387bef9e1d5f503bd8c1c0...
# 9  702e4598004745673c0f6b50387bef9e1d5f503bd8c1c0...
#
#                                            user_tier  \
# 0  d74a5cebc23c56af60a5768c22d44b52f598629d4011fa...
# 1  d74a5cebc23c56af60a5768c22d44b52f598629d4011fa...
# 2  d74a5cebc23c56af60a5768c22d44b52f598629d4011fa...
# 3  d74a5cebc23c56af60a5768c22d44b52f598629d4011fa...
# 4  d74a5cebc23c56af60a5768c22d44b52f598629d4011fa...
# 5  d74a5cebc23c56af60a5768c22d44b52f598629d4011fa...
# 6  d74a5cebc23c56af60a5768c22d44b52f598629d4011fa...
# 7  d74a5cebc23c56af60a5768c22d44b52f598629d4011fa...
# 8  d74a5cebc23c56af60a5768c22d44b52f598629d4011fa...
# 9  d74a5cebc23c56af60a5768c22d44b52f598629d4011fa...
#
#                                         user_country context_type  \
# 0  ea2f413bd8fda0b91a814a68aa520044b204796991a343...   product_id
# 1  ea2f413bd8fda0b91a814a68aa520044b204796991a343...   product_id
# 2  ea2f413bd8fda0b91a814a68aa520044b204796991a343...   product_id
# 3  ea2f413bd8fda0b91a814a68aa520044b204796991a343...   product_id
# 4  ea2f413bd8fda0b91a814a68aa520044b204796991a343...   product_id
# 5  ea2f413bd8fda0b91a814a68aa520044b204796991a343...   product_id
# 6  ea2f413bd8fda0b91a814a68aa520044b204796991a343...   product_id
# 7  ea2f413bd8fda0b91a814a68aa520044b204796991a343...   product_id
# 8  ea2f413bd8fda0b91a814a68aa520044b204796991a343...   product_id
# 9  ea2f413bd8fda0b91a814a68aa520044b204796991a343...   product_id
#
#                                        context_value  product_price  week  \
# 0  a6e9c2a832972484be2bd4378135743d1d00d651502c38...       0.000466     6
# 1  a6e9c2a832972484be2bd4378135743d1d00d651502c38...       0.001068     6
# 2  a6e9c2a832972484be2bd4378135743d1d00d651502c38...       0.001238     6
# 3  a6e9c2a832972484be2bd4378135743d1d00d651502c38...       0.000465     6
# 4  a6e9c2a832972484be2bd4378135743d1d00d651502c38...       0.000936     6
# 5  a6e9c2a832972484be2bd4378135743d1d00d651502c38...       0.001765     6
# 6  ca0bdabcd3a4eae25db6f95687cb307200e78892a6d774...       0.000804     7
# 7  ca0bdabcd3a4eae25db6f95687cb307200e78892a6d774...       0.000722     7
# 8  ca0bdabcd3a4eae25db6f95687cb307200e78892a6d774...       0.000916     7
# 9  ca0bdabcd3a4eae25db6f95687cb307200e78892a6d774...       0.000761     7
#
#    week_day  is_click
# 0         6         0
# 1         6         0
# 2         6         1
# 3         6         0
# 4         6         0
# 5         6         0
# 6         2         0
# 7         2         0
# 8         2         1
# 9         2         0

# %%
train.isnull().sum()
# Out:
# query_id              0
# user_id               0
# session_id            0
# product_id            0
# page_type             0
# previous_page_type    0
# device_category       0
# device_platform       0
# user_tier             0
# user_country          0
# context_type          0
# context_value         0
# product_price         0
# week                  0
# week_day              0
# is_click              0
# dtype: int64

# %%
data = pd.concat([train[list(set(train.columns)-set(['is_click']))], val, test], axis=0)
data = data.reset_index(drop=True)

# %%
all_products = data.product_id.apply(str).tolist()

# %%
unique_products = OrderedSet(all_products)

# %%
train_session_interactions = dict(train.groupby('session_id')['product_id'].apply(list))
val_session_interactions = dict(val.groupby('session_id')['product_id'].apply(list))
test_session_interactions = dict(test.groupby('session_id')['product_id'].apply(list))

train_session_actions = dict(train.groupby('session_id')['is_click'].apply(list))
# val_session_actions = dict(val.groupby('session_id')['is_click'].apply(list))

# %%
train['days_elapsed'] = (train['week'].astype(int)-1)*7 + train['week_day'].astype(int)
val['days_elapsed'] = (val['week'].astype(int)-1)*7 + val['week_day'].astype(int)
test['days_elapsed'] = (test['week'].astype(int)-1)*7 + test['week_day'].astype(int)

# %%
days_elapsed = pd.DataFrame(train.groupby('session_id')['days_elapsed'].apply(list)).reset_index()
days_elapsed = days_elapsed.rename(columns = {'days_elapsed': 'days_elapsed_list'})
days_elapsed.head(2)
# Out:
#                                           session_id         days_elapsed_list
# 0  00000310a3874db670d94513217ac53d73be25ea0bc1c9...  [41, 41, 41, 41, 41, 41]
# 1  000055d87de3ef0e5c614ce4ec6c04a37405d767332477...  [46, 46, 46, 46, 46, 46]

# %%
train = train.merge(days_elapsed, on='session_id', how='left')
train.head(10)
# Out:
#                                             query_id  \
# 0  0000437da0efd6e292f12a8a3bf7525de5bd05b5807a74...
# 1  0000437da0efd6e292f12a8a3bf7525de5bd05b5807a74...
# 2  0000437da0efd6e292f12a8a3bf7525de5bd05b5807a74...
# 3  0000437da0efd6e292f12a8a3bf7525de5bd05b5807a74...
# 4  0000437da0efd6e292f12a8a3bf7525de5bd05b5807a74...
# 5  0000437da0efd6e292f12a8a3bf7525de5bd05b5807a74...
# 6  00008bcf52759e7e70d533026da637b1cfeb0dc04a67ed...
# 7  00008bcf52759e7e70d533026da637b1cfeb0dc04a67ed...
# 8  00008bcf52759e7e70d533026da637b1cfeb0dc04a67ed...
# 9  00008bcf52759e7e70d533026da637b1cfeb0dc04a67ed...
#
#                                              user_id  \
# 0  ff2088c2fd3bf9cb8c2601252dd65a99201f59972820d3...
# 1  ff2088c2fd3bf9cb8c2601252dd65a99201f59972820d3...
# 2  ff2088c2fd3bf9cb8c2601252dd65a99201f59972820d3...
# 3  ff2088c2fd3bf9cb8c2601252dd65a99201f59972820d3...
# 4  ff2088c2fd3bf9cb8c2601252dd65a99201f59972820d3...
# 5  ff2088c2fd3bf9cb8c2601252dd65a99201f59972820d3...
# 6  968f154cc29e3fb1ed5f361ab23d9d8495cf47c5baefef...
# 7  968f154cc29e3fb1ed5f361ab23d9d8495cf47c5baefef...
# 8  968f154cc29e3fb1ed5f361ab23d9d8495cf47c5baefef...
# 9  968f154cc29e3fb1ed5f361ab23d9d8495cf47c5baefef...
#
#                                           session_id  \
# 0  37b65411191e2f12441edad785c6ae94741eceaffdcb80...
# 1  37b65411191e2f12441edad785c6ae94741eceaffdcb80...
# 2  37b65411191e2f12441edad785c6ae94741eceaffdcb80...
# 3  37b65411191e2f12441edad785c6ae94741eceaffdcb80...
# 4  37b65411191e2f12441edad785c6ae94741eceaffdcb80...
# 5  37b65411191e2f12441edad785c6ae94741eceaffdcb80...
# 6  f391f67a9d273be5a95460ce4756cdbc22430336a0b28d...
# 7  f391f67a9d273be5a95460ce4756cdbc22430336a0b28d...
# 8  f391f67a9d273be5a95460ce4756cdbc22430336a0b28d...
# 9  f391f67a9d273be5a95460ce4756cdbc22430336a0b28d...
#
#                                           product_id  \
# 0  1efd18182268101b62a1ea12a9cafbe05487f3abb92924...
# 1  62349c6eda0dc9fe8bb023213f03ebe93aefa5cbcdfecf...
# 2  aa0bbdfa55326b5c08d3472b1ee1d56fe13a82f63f46c8...
# 3  793301d78ea43b599acf05d350c8f9e485f5deaa417284...
# 4  9e03ca4af958bef1ce5d54e684a40ee7e3a9aa7e5010b6...
# 5  9e7f6f10b18f35ce924575f599465265e22fa9d75b13c9...
# 6  b08c37eac9adf04388a290b13105167b4a50911ac14e5c...
# 7  7b8c68e43264904ec9f74df2b9461fe7381aab12d0740e...
# 8  616636f3c60f43d24741d9eca7fe1c3c567825acc64348...
# 9  01f0a57f4fbc0e42e76960238fce01c28e29f23819ae04...
#
#                                            page_type  \
# 0  06a7f8e972f61aeb0e06335699518079a444e4450ff766...
# 1  06a7f8e972f61aeb0e06335699518079a444e4450ff766...
# 2  06a7f8e972f61aeb0e06335699518079a444e4450ff766...
# 3  06a7f8e972f61aeb0e06335699518079a444e4450ff766...
# 4  06a7f8e972f61aeb0e06335699518079a444e4450ff766...
# 5  06a7f8e972f61aeb0e06335699518079a444e4450ff766...
# 6  06a7f8e972f61aeb0e06335699518079a444e4450ff766...
# 7  06a7f8e972f61aeb0e06335699518079a444e4450ff766...
# 8  06a7f8e972f61aeb0e06335699518079a444e4450ff766...
# 9  06a7f8e972f61aeb0e06335699518079a444e4450ff766...
#
#                                   previous_page_type  \
# 0  d05d943023ee7c2091506a72ce25841e84f88a4233a11d...
# 1  d05d943023ee7c2091506a72ce25841e84f88a4233a11d...
# 2  d05d943023ee7c2091506a72ce25841e84f88a4233a11d...
# 3  d05d943023ee7c2091506a72ce25841e84f88a4233a11d...
# 4  d05d943023ee7c2091506a72ce25841e84f88a4233a11d...
# 5  d05d943023ee7c2091506a72ce25841e84f88a4233a11d...
# 6  c9f34437ce0e536fefd11a34b9a411b541d2dabfec872a...
# 7  c9f34437ce0e536fefd11a34b9a411b541d2dabfec872a...
# 8  c9f34437ce0e536fefd11a34b9a411b541d2dabfec872a...
# 9  c9f34437ce0e536fefd11a34b9a411b541d2dabfec872a...
#
#                                      device_category  \
# 0  bf2241c08d92d32a6782b4041a2c11ca58882ca88454b3...
# 1  bf2241c08d92d32a6782b4041a2c11ca58882ca88454b3...
# 2  bf2241c08d92d32a6782b4041a2c11ca58882ca88454b3...
# 3  bf2241c08d92d32a6782b4041a2c11ca58882ca88454b3...
# 4  bf2241c08d92d32a6782b4041a2c11ca58882ca88454b3...
# 5  bf2241c08d92d32a6782b4041a2c11ca58882ca88454b3...
# 6  bf2241c08d92d32a6782b4041a2c11ca58882ca88454b3...
# 7  bf2241c08d92d32a6782b4041a2c11ca58882ca88454b3...
# 8  bf2241c08d92d32a6782b4041a2c11ca58882ca88454b3...
# 9  bf2241c08d92d32a6782b4041a2c11ca58882ca88454b3...
#
#                                      device_platform  \
# 0  702e4598004745673c0f6b50387bef9e1d5f503bd8c1c0...
# 1  702e4598004745673c0f6b50387bef9e1d5f503bd8c1c0...
# 2  702e4598004745673c0f6b50387bef9e1d5f503bd8c1c0...
# 3  702e4598004745673c0f6b50387bef9e1d5f503bd8c1c0...
# 4  702e4598004745673c0f6b50387bef9e1d5f503bd8c1c0...
# 5  702e4598004745673c0f6b50387bef9e1d5f503bd8c1c0...
# 6  702e4598004745673c0f6b50387bef9e1d5f503bd8c1c0...
# 7  702e4598004745673c0f6b50387bef9e1d5f503bd8c1c0...
# 8  702e4598004745673c0f6b50387bef9e1d5f503bd8c1c0...
# 9  702e4598004745673c0f6b50387bef9e1d5f503bd8c1c0...
#
#                                            user_tier  \
# 0  d74a5cebc23c56af60a5768c22d44b52f598629d4011fa...
# 1  d74a5cebc23c56af60a5768c22d44b52f598629d4011fa...
# 2  d74a5cebc23c56af60a5768c22d44b52f598629d4011fa...
# 3  d74a5cebc23c56af60a5768c22d44b52f598629d4011fa...
# 4  d74a5cebc23c56af60a5768c22d44b52f598629d4011fa...
# 5  d74a5cebc23c56af60a5768c22d44b52f598629d4011fa...
# 6  d74a5cebc23c56af60a5768c22d44b52f598629d4011fa...
# 7  d74a5cebc23c56af60a5768c22d44b52f598629d4011fa...
# 8  d74a5cebc23c56af60a5768c22d44b52f598629d4011fa...
# 9  d74a5cebc23c56af60a5768c22d44b52f598629d4011fa...
#
#                                         user_country context_type  \
# 0  ea2f413bd8fda0b91a814a68aa520044b204796991a343...   product_id
# 1  ea2f413bd8fda0b91a814a68aa520044b204796991a343...   product_id
# 2  ea2f413bd8fda0b91a814a68aa520044b204796991a343...   product_id
# 3  ea2f413bd8fda0b91a814a68aa520044b204796991a343...   product_id
# 4  ea2f413bd8fda0b91a814a68aa520044b204796991a343...   product_id
# 5  ea2f413bd8fda0b91a814a68aa520044b204796991a343...   product_id
# 6  ea2f413bd8fda0b91a814a68aa520044b204796991a343...   product_id
# 7  ea2f413bd8fda0b91a814a68aa520044b204796991a343...   product_id
# 8  ea2f413bd8fda0b91a814a68aa520044b204796991a343...   product_id
# 9  ea2f413bd8fda0b91a814a68aa520044b204796991a343...   product_id
#
#                                        context_value  product_price  week  \
# 0  a6e9c2a832972484be2bd4378135743d1d00d651502c38...       0.000466     6
# 1  a6e9c2a832972484be2bd4378135743d1d00d651502c38...       0.001068     6
# 2  a6e9c2a832972484be2bd4378135743d1d00d651502c38...       0.001238     6
# 3  a6e9c2a832972484be2bd4378135743d1d00d651502c38...       0.000465     6
# 4  a6e9c2a832972484be2bd4378135743d1d00d651502c38...       0.000936     6
# 5  a6e9c2a832972484be2bd4378135743d1d00d651502c38...       0.001765     6
# 6  ca0bdabcd3a4eae25db6f95687cb307200e78892a6d774...       0.000804     7
# 7  ca0bdabcd3a4eae25db6f95687cb307200e78892a6d774...       0.000722     7
# 8  ca0bdabcd3a4eae25db6f95687cb307200e78892a6d774...       0.000916     7
# 9  ca0bdabcd3a4eae25db6f95687cb307200e78892a6d774...       0.000761     7
#
#    week_day  is_click  days_elapsed  \
# 0         6         0            41
# 1         6         0            41
# 2         6         1            41
# 3         6         0            41
# 4         6         0            41
# 5         6         0            41
# 6         2         0            44
# 7         2         0            44
# 8         2         1            44
# 9         2         0            44
#
#                                    days_elapsed_list
# 0                           [41, 41, 41, 41, 41, 41]
# 1                           [41, 41, 41, 41, 41, 41]
# 2                           [41, 41, 41, 41, 41, 41]
# 3                           [41, 41, 41, 41, 41, 41]
# 4                           [41, 41, 41, 41, 41, 41]
# 5                           [41, 41, 41, 41, 41, 41]
# 6  [44, 44, 44, 44, 44, 44, 44, 44, 44, 44, 44, 4...
# 7  [44, 44, 44, 44, 44, 44, 44, 44, 44, 44, 44, 4...
# 8  [44, 44, 44, 44, 44, 44, 44, 44, 44, 44, 44, 4...
# 9  [44, 44, 44, 44, 44, 44, 44, 44, 44, 44, 44, 4...

# %%
len(train), len(train.groupby('session_id')['days_elapsed'].rank(method='dense').apply(int)), train.session_id.nunique()
# Out:
# (3507990, 3507990, 317426)

# %%
train['user_step'] = train.groupby('user_id')['days_elapsed'].rank(method='dense').apply(int)
val['user_step'] = val.groupby('user_id')['days_elapsed'].rank(method='dense').apply(int)
test['user_step'] = test.groupby('user_id')['days_elapsed'].rank(method='dense').apply(int)

# train['sess_step'] = train['sess_step']//6
# val['sess_step'] = val['sess_step']//6

# %%
train['user_step'].unique()
# Out:
# array([ 3,  1,  2, 25,  7, 16,  4, 14, 12,  5,  8, 17, 19,  6, 11, 29, 20,
#         9, 10, 23, 13, 18, 22, 27, 15, 26, 43, 34, 31, 21, 41, 24, 28, 30,
#        40, 38, 32, 44, 39, 37, 33, 36, 35, 42, 45])

# %%
# train['sess_step'].unique()
train.head()
# Out:
#                                             query_id  \
# 0  0000437da0efd6e292f12a8a3bf7525de5bd05b5807a74...
# 1  0000437da0efd6e292f12a8a3bf7525de5bd05b5807a74...
# 2  0000437da0efd6e292f12a8a3bf7525de5bd05b5807a74...
# 3  0000437da0efd6e292f12a8a3bf7525de5bd05b5807a74...
# 4  0000437da0efd6e292f12a8a3bf7525de5bd05b5807a74...
#
#                                              user_id  \
# 0  ff2088c2fd3bf9cb8c2601252dd65a99201f59972820d3...
# 1  ff2088c2fd3bf9cb8c2601252dd65a99201f59972820d3...
# 2  ff2088c2fd3bf9cb8c2601252dd65a99201f59972820d3...
# 3  ff2088c2fd3bf9cb8c2601252dd65a99201f59972820d3...
# 4  ff2088c2fd3bf9cb8c2601252dd65a99201f59972820d3...
#
#                                           session_id  \
# 0  37b65411191e2f12441edad785c6ae94741eceaffdcb80...
# 1  37b65411191e2f12441edad785c6ae94741eceaffdcb80...
# 2  37b65411191e2f12441edad785c6ae94741eceaffdcb80...
# 3  37b65411191e2f12441edad785c6ae94741eceaffdcb80...
# 4  37b65411191e2f12441edad785c6ae94741eceaffdcb80...
#
#                                           product_id  \
# 0  1efd18182268101b62a1ea12a9cafbe05487f3abb92924...
# 1  62349c6eda0dc9fe8bb023213f03ebe93aefa5cbcdfecf...
# 2  aa0bbdfa55326b5c08d3472b1ee1d56fe13a82f63f46c8...
# 3  793301d78ea43b599acf05d350c8f9e485f5deaa417284...
# 4  9e03ca4af958bef1ce5d54e684a40ee7e3a9aa7e5010b6...
#
#                                            page_type  \
# 0  06a7f8e972f61aeb0e06335699518079a444e4450ff766...
# 1  06a7f8e972f61aeb0e06335699518079a444e4450ff766...
# 2  06a7f8e972f61aeb0e06335699518079a444e4450ff766...
# 3  06a7f8e972f61aeb0e06335699518079a444e4450ff766...
# 4  06a7f8e972f61aeb0e06335699518079a444e4450ff766...
#
#                                   previous_page_type  \
# 0  d05d943023ee7c2091506a72ce25841e84f88a4233a11d...
# 1  d05d943023ee7c2091506a72ce25841e84f88a4233a11d...
# 2  d05d943023ee7c2091506a72ce25841e84f88a4233a11d...
# 3  d05d943023ee7c2091506a72ce25841e84f88a4233a11d...
# 4  d05d943023ee7c2091506a72ce25841e84f88a4233a11d...
#
#                                      device_category  \
# 0  bf2241c08d92d32a6782b4041a2c11ca58882ca88454b3...
# 1  bf2241c08d92d32a6782b4041a2c11ca58882ca88454b3...
# 2  bf2241c08d92d32a6782b4041a2c11ca58882ca88454b3...
# 3  bf2241c08d92d32a6782b4041a2c11ca58882ca88454b3...
# 4  bf2241c08d92d32a6782b4041a2c11ca58882ca88454b3...
#
#                                      device_platform  \
# 0  702e4598004745673c0f6b50387bef9e1d5f503bd8c1c0...
# 1  702e4598004745673c0f6b50387bef9e1d5f503bd8c1c0...
# 2  702e4598004745673c0f6b50387bef9e1d5f503bd8c1c0...
# 3  702e4598004745673c0f6b50387bef9e1d5f503bd8c1c0...
# 4  702e4598004745673c0f6b50387bef9e1d5f503bd8c1c0...
#
#                                            user_tier  \
# 0  d74a5cebc23c56af60a5768c22d44b52f598629d4011fa...
# 1  d74a5cebc23c56af60a5768c22d44b52f598629d4011fa...
# 2  d74a5cebc23c56af60a5768c22d44b52f598629d4011fa...
# 3  d74a5cebc23c56af60a5768c22d44b52f598629d4011fa...
# 4  d74a5cebc23c56af60a5768c22d44b52f598629d4011fa...
#
#                                         user_country context_type  \
# 0  ea2f413bd8fda0b91a814a68aa520044b204796991a343...   product_id
# 1  ea2f413bd8fda0b91a814a68aa520044b204796991a343...   product_id
# 2  ea2f413bd8fda0b91a814a68aa520044b204796991a343...   product_id
# 3  ea2f413bd8fda0b91a814a68aa520044b204796991a343...   product_id
# 4  ea2f413bd8fda0b91a814a68aa520044b204796991a343...   product_id
#
#                                        context_value  product_price  week  \
# 0  a6e9c2a832972484be2bd4378135743d1d00d651502c38...       0.000466     6
# 1  a6e9c2a832972484be2bd4378135743d1d00d651502c38...       0.001068     6
# 2  a6e9c2a832972484be2bd4378135743d1d00d651502c38...       0.001238     6
# 3  a6e9c2a832972484be2bd4378135743d1d00d651502c38...       0.000465     6
# 4  a6e9c2a832972484be2bd4378135743d1d00d651502c38...       0.000936     6
#
#    week_day  is_click  days_elapsed         days_elapsed_list  user_step
# 0         6         0            41  [41, 41, 41, 41, 41, 41]          3
# 1         6         0            41  [41, 41, 41, 41, 41, 41]          3
# 2         6         1            41  [41, 41, 41, 41, 41, 41]          3
# 3         6         0            41  [41, 41, 41, 41, 41, 41]          3
# 4         6         0            41  [41, 41, 41, 41, 41, 41]          3

# %%
gc.collect()
# Out:
# 110

# %%
train['price_rank'] = train.groupby('query_id')['product_price'].rank(method='dense').apply(int)
val['price_rank'] = val.groupby('query_id')['product_price'].rank(method='dense').apply(int)
test['price_rank'] = test.groupby('query_id')['product_price'].rank(method='dense').apply(int)

# %%
# def apply_rank_normalize(row):
#     if row["price_rank"]%6==0:
#         return 6
#     else:
#         return row["price_rank"]%6

# train['price_rank'] = train.swifter.apply(lambda x: apply_rank_normalize(x), 1)
# val['price_rank'] = val.swifter.apply(lambda x: apply_rank_normalize(x), 1)

# %%
train.head()
# Out:
#                                             query_id  \
# 0  0000437da0efd6e292f12a8a3bf7525de5bd05b5807a74...
# 1  0000437da0efd6e292f12a8a3bf7525de5bd05b5807a74...
# 2  0000437da0efd6e292f12a8a3bf7525de5bd05b5807a74...
# 3  0000437da0efd6e292f12a8a3bf7525de5bd05b5807a74...
# 4  0000437da0efd6e292f12a8a3bf7525de5bd05b5807a74...
#
#                                              user_id  \
# 0  ff2088c2fd3bf9cb8c2601252dd65a99201f59972820d3...
# 1  ff2088c2fd3bf9cb8c2601252dd65a99201f59972820d3...
# 2  ff2088c2fd3bf9cb8c2601252dd65a99201f59972820d3...
# 3  ff2088c2fd3bf9cb8c2601252dd65a99201f59972820d3...
# 4  ff2088c2fd3bf9cb8c2601252dd65a99201f59972820d3...
#
#                                           session_id  \
# 0  37b65411191e2f12441edad785c6ae94741eceaffdcb80...
# 1  37b65411191e2f12441edad785c6ae94741eceaffdcb80...
# 2  37b65411191e2f12441edad785c6ae94741eceaffdcb80...
# 3  37b65411191e2f12441edad785c6ae94741eceaffdcb80...
# 4  37b65411191e2f12441edad785c6ae94741eceaffdcb80...
#
#                                           product_id  \
# 0  1efd18182268101b62a1ea12a9cafbe05487f3abb92924...
# 1  62349c6eda0dc9fe8bb023213f03ebe93aefa5cbcdfecf...
# 2  aa0bbdfa55326b5c08d3472b1ee1d56fe13a82f63f46c8...
# 3  793301d78ea43b599acf05d350c8f9e485f5deaa417284...
# 4  9e03ca4af958bef1ce5d54e684a40ee7e3a9aa7e5010b6...
#
#                                            page_type  \
# 0  06a7f8e972f61aeb0e06335699518079a444e4450ff766...
# 1  06a7f8e972f61aeb0e06335699518079a444e4450ff766...
# 2  06a7f8e972f61aeb0e06335699518079a444e4450ff766...
# 3  06a7f8e972f61aeb0e06335699518079a444e4450ff766...
# 4  06a7f8e972f61aeb0e06335699518079a444e4450ff766...
#
#                                   previous_page_type  \
# 0  d05d943023ee7c2091506a72ce25841e84f88a4233a11d...
# 1  d05d943023ee7c2091506a72ce25841e84f88a4233a11d...
# 2  d05d943023ee7c2091506a72ce25841e84f88a4233a11d...
# 3  d05d943023ee7c2091506a72ce25841e84f88a4233a11d...
# 4  d05d943023ee7c2091506a72ce25841e84f88a4233a11d...
#
#                                      device_category  \
# 0  bf2241c08d92d32a6782b4041a2c11ca58882ca88454b3...
# 1  bf2241c08d92d32a6782b4041a2c11ca58882ca88454b3...
# 2  bf2241c08d92d32a6782b4041a2c11ca58882ca88454b3...
# 3  bf2241c08d92d32a6782b4041a2c11ca58882ca88454b3...
# 4  bf2241c08d92d32a6782b4041a2c11ca58882ca88454b3...
#
#                                      device_platform  \
# 0  702e4598004745673c0f6b50387bef9e1d5f503bd8c1c0...
# 1  702e4598004745673c0f6b50387bef9e1d5f503bd8c1c0...
# 2  702e4598004745673c0f6b50387bef9e1d5f503bd8c1c0...
# 3  702e4598004745673c0f6b50387bef9e1d5f503bd8c1c0...
# 4  702e4598004745673c0f6b50387bef9e1d5f503bd8c1c0...
#
#                                            user_tier  \
# 0  d74a5cebc23c56af60a5768c22d44b52f598629d4011fa...
# 1  d74a5cebc23c56af60a5768c22d44b52f598629d4011fa...
# 2  d74a5cebc23c56af60a5768c22d44b52f598629d4011fa...
# 3  d74a5cebc23c56af60a5768c22d44b52f598629d4011fa...
# 4  d74a5cebc23c56af60a5768c22d44b52f598629d4011fa...
#
#                                         user_country context_type  \
# 0  ea2f413bd8fda0b91a814a68aa520044b204796991a343...   product_id
# 1  ea2f413bd8fda0b91a814a68aa520044b204796991a343...   product_id
# 2  ea2f413bd8fda0b91a814a68aa520044b204796991a343...   product_id
# 3  ea2f413bd8fda0b91a814a68aa520044b204796991a343...   product_id
# 4  ea2f413bd8fda0b91a814a68aa520044b204796991a343...   product_id
#
#                                        context_value  product_price  week  \
# 0  a6e9c2a832972484be2bd4378135743d1d00d651502c38...       0.000466     6
# 1  a6e9c2a832972484be2bd4378135743d1d00d651502c38...       0.001068     6
# 2  a6e9c2a832972484be2bd4378135743d1d00d651502c38...       0.001238     6
# 3  a6e9c2a832972484be2bd4378135743d1d00d651502c38...       0.000465     6
# 4  a6e9c2a832972484be2bd4378135743d1d00d651502c38...       0.000936     6
#
#    week_day  is_click  days_elapsed         days_elapsed_list  user_step  \
# 0         6         0            41  [41, 41, 41, 41, 41, 41]          3
# 1         6         0            41  [41, 41, 41, 41, 41, 41]          3
# 2         6         1            41  [41, 41, 41, 41, 41, 41]          3
# 3         6         0            41  [41, 41, 41, 41, 41, 41]          3
# 4         6         0            41  [41, 41, 41, 41, 41, 41]          3
#
#    price_rank
# 0           2
# 1           4
# 2           5
# 3           1
# 4           3

# %%
train.price_rank.unique()
# Out:
# array([2, 4, 5, 1, 3, 6])

# %%
attributes_df = pd.read_parquet("../data_phase1/attributes.parquet")
attributes_df.head(2)
# Out:
#                                           product_id  \
# 0  0013f07ccdf212210c110e63f0de46e37669c17a4d855a...
# 1  002239cd57f19f22e557030dff363dfbd1344d8f7ac829...
#
#                                               gender  \
# 0  a8c9cca4c116691f1e331a5058e84f05e31696bc4f611c...
# 1  4a00d8b84bdb2ec2f219304d3883a46336f9fb38d2f1e6...
#
#                                          main_colour  \
# 0  7673fc4fdc325f3785a223787d2b32e381e8b4c1c8a765...
# 1  0f97dafafa5dc4bb18853ea00776dfcc52302f40411b50...
#
#                                        second_colour  \
# 0  4737cd35940c2338e96c18a25aeb6848d46f0da795bce8...
# 1  ca8c396e7422e324d4454a911e0319d07b85a4fb89b006...
#
#                                               season  \
# 0  847a067597e39838f1f85b0774f44e68b4d6e64d3ec4dd...
# 1  9db35d237f5873f0410d3ca18c07430270086eb1e7838d...
#
#                                           collection  \
# 0  a3791e8d85c005b0d9d60d6d3b7e8edd2f256a5cc928d0...
# 1  a3791e8d85c005b0d9d60d6d3b7e8edd2f256a5cc928d0...
#
#                                       category_id_l1  \
# 0  abf367e49718254e068eee51a565fdcede2d741e4c7e33...
# 1  e54f8513b708db3afdbd4950bd3420579a8cddabf4c1b3...
#
#                                       category_id_l2  \
# 0  61fe255948ec07c4eb25c70f7144b54beddd00466ad866...
# 1  3809cade495cd7dc289e6aee521d380549ebd3456f03bc...
#
#                                       category_id_l3  \
# 0  05f872d8b8ec85642ad49786d6e443c0df6e7df4bdcba3...
# 1  fd021cd2dbaf0d7b6105a1b136cf5a094e025010a2096f...
#
#                                             brand_id  \
# 0  dd6ea8954a945ef0889f30d57b7fdb8d6aaad397e6c6ff...
# 1  a6536c6bc250d525ccd3b63a3ec483a33a2010422932a3...
#
#                                          season_year  start_online_date  \
# 0  c7c4ac6af030e54d02b9e4545e4223e76515c3ce4e498e...        1067.041667
# 1  ef7d8d2e02aec8c328dafde95486f7181c37d07be3d167...         215.041667
#
#                                      material_values  \
# 0  f61ecea9b45f1590e57706b88207449bdd4cb703b917ad...
# 1  1675f293342bbb518ba3a5ad39399aa0a13580653d253e...
#
#                                     attribute_values
# 0  8b45c5d5e010acf257787f2ce0c505857d94709c436991...
# 1  ca8c396e7422e324d4454a911e0319d07b85a4fb89b006...

# %%
train = train.merge(attributes_df[["product_id", "start_online_date"]], on="product_id", how="left")
val = val.merge(attributes_df[["product_id", "start_online_date"]], on="product_id", how="left")
test = test.merge(attributes_df[["product_id", "start_online_date"]], on="product_id", how="left")

# %%
train['start_online_date_rank'] = train.groupby('query_id')['start_online_date'].rank(method='dense').apply(int)
val['start_online_date_rank'] = val.groupby('query_id')['start_online_date'].rank(method='dense').apply(int)
test['start_online_date_rank'] = test.groupby('query_id')['start_online_date'].rank(method='dense').apply(int)

# %%
train.start_online_date_rank.unique(), val.start_online_date_rank.unique()
# Out:
# (array([6, 3, 2, 5, 4, 1]), array([3, 6, 5, 1, 2, 4]))

# %%
train.head(10)
# Out:
#                                             query_id  \
# 0  0000437da0efd6e292f12a8a3bf7525de5bd05b5807a74...
# 1  0000437da0efd6e292f12a8a3bf7525de5bd05b5807a74...
# 2  0000437da0efd6e292f12a8a3bf7525de5bd05b5807a74...
# 3  0000437da0efd6e292f12a8a3bf7525de5bd05b5807a74...
# 4  0000437da0efd6e292f12a8a3bf7525de5bd05b5807a74...
# 5  0000437da0efd6e292f12a8a3bf7525de5bd05b5807a74...
# 6  00008bcf52759e7e70d533026da637b1cfeb0dc04a67ed...
# 7  00008bcf52759e7e70d533026da637b1cfeb0dc04a67ed...
# 8  00008bcf52759e7e70d533026da637b1cfeb0dc04a67ed...
# 9  00008bcf52759e7e70d533026da637b1cfeb0dc04a67ed...
#
#                                              user_id  \
# 0  ff2088c2fd3bf9cb8c2601252dd65a99201f59972820d3...
# 1  ff2088c2fd3bf9cb8c2601252dd65a99201f59972820d3...
# 2  ff2088c2fd3bf9cb8c2601252dd65a99201f59972820d3...
# 3  ff2088c2fd3bf9cb8c2601252dd65a99201f59972820d3...
# 4  ff2088c2fd3bf9cb8c2601252dd65a99201f59972820d3...
# 5  ff2088c2fd3bf9cb8c2601252dd65a99201f59972820d3...
# 6  968f154cc29e3fb1ed5f361ab23d9d8495cf47c5baefef...
# 7  968f154cc29e3fb1ed5f361ab23d9d8495cf47c5baefef...
# 8  968f154cc29e3fb1ed5f361ab23d9d8495cf47c5baefef...
# 9  968f154cc29e3fb1ed5f361ab23d9d8495cf47c5baefef...
#
#                                           session_id  \
# 0  37b65411191e2f12441edad785c6ae94741eceaffdcb80...
# 1  37b65411191e2f12441edad785c6ae94741eceaffdcb80...
# 2  37b65411191e2f12441edad785c6ae94741eceaffdcb80...
# 3  37b65411191e2f12441edad785c6ae94741eceaffdcb80...
# 4  37b65411191e2f12441edad785c6ae94741eceaffdcb80...
# 5  37b65411191e2f12441edad785c6ae94741eceaffdcb80...
# 6  f391f67a9d273be5a95460ce4756cdbc22430336a0b28d...
# 7  f391f67a9d273be5a95460ce4756cdbc22430336a0b28d...
# 8  f391f67a9d273be5a95460ce4756cdbc22430336a0b28d...
# 9  f391f67a9d273be5a95460ce4756cdbc22430336a0b28d...
#
#                                           product_id  \
# 0  1efd18182268101b62a1ea12a9cafbe05487f3abb92924...
# 1  62349c6eda0dc9fe8bb023213f03ebe93aefa5cbcdfecf...
# 2  aa0bbdfa55326b5c08d3472b1ee1d56fe13a82f63f46c8...
# 3  793301d78ea43b599acf05d350c8f9e485f5deaa417284...
# 4  9e03ca4af958bef1ce5d54e684a40ee7e3a9aa7e5010b6...
# 5  9e7f6f10b18f35ce924575f599465265e22fa9d75b13c9...
# 6  b08c37eac9adf04388a290b13105167b4a50911ac14e5c...
# 7  7b8c68e43264904ec9f74df2b9461fe7381aab12d0740e...
# 8  616636f3c60f43d24741d9eca7fe1c3c567825acc64348...
# 9  01f0a57f4fbc0e42e76960238fce01c28e29f23819ae04...
#
#                                            page_type  \
# 0  06a7f8e972f61aeb0e06335699518079a444e4450ff766...
# 1  06a7f8e972f61aeb0e06335699518079a444e4450ff766...
# 2  06a7f8e972f61aeb0e06335699518079a444e4450ff766...
# 3  06a7f8e972f61aeb0e06335699518079a444e4450ff766...
# 4  06a7f8e972f61aeb0e06335699518079a444e4450ff766...
# 5  06a7f8e972f61aeb0e06335699518079a444e4450ff766...
# 6  06a7f8e972f61aeb0e06335699518079a444e4450ff766...
# 7  06a7f8e972f61aeb0e06335699518079a444e4450ff766...
# 8  06a7f8e972f61aeb0e06335699518079a444e4450ff766...
# 9  06a7f8e972f61aeb0e06335699518079a444e4450ff766...
#
#                                   previous_page_type  \
# 0  d05d943023ee7c2091506a72ce25841e84f88a4233a11d...
# 1  d05d943023ee7c2091506a72ce25841e84f88a4233a11d...
# 2  d05d943023ee7c2091506a72ce25841e84f88a4233a11d...
# 3  d05d943023ee7c2091506a72ce25841e84f88a4233a11d...
# 4  d05d943023ee7c2091506a72ce25841e84f88a4233a11d...
# 5  d05d943023ee7c2091506a72ce25841e84f88a4233a11d...
# 6  c9f34437ce0e536fefd11a34b9a411b541d2dabfec872a...
# 7  c9f34437ce0e536fefd11a34b9a411b541d2dabfec872a...
# 8  c9f34437ce0e536fefd11a34b9a411b541d2dabfec872a...
# 9  c9f34437ce0e536fefd11a34b9a411b541d2dabfec872a...
#
#                                      device_category  \
# 0  bf2241c08d92d32a6782b4041a2c11ca58882ca88454b3...
# 1  bf2241c08d92d32a6782b4041a2c11ca58882ca88454b3...
# 2  bf2241c08d92d32a6782b4041a2c11ca58882ca88454b3...
# 3  bf2241c08d92d32a6782b4041a2c11ca58882ca88454b3...
# 4  bf2241c08d92d32a6782b4041a2c11ca58882ca88454b3...
# 5  bf2241c08d92d32a6782b4041a2c11ca58882ca88454b3...
# 6  bf2241c08d92d32a6782b4041a2c11ca58882ca88454b3...
# 7  bf2241c08d92d32a6782b4041a2c11ca58882ca88454b3...
# 8  bf2241c08d92d32a6782b4041a2c11ca58882ca88454b3...
# 9  bf2241c08d92d32a6782b4041a2c11ca58882ca88454b3...
#
#                                      device_platform  \
# 0  702e4598004745673c0f6b50387bef9e1d5f503bd8c1c0...
# 1  702e4598004745673c0f6b50387bef9e1d5f503bd8c1c0...
# 2  702e4598004745673c0f6b50387bef9e1d5f503bd8c1c0...
# 3  702e4598004745673c0f6b50387bef9e1d5f503bd8c1c0...
# 4  702e4598004745673c0f6b50387bef9e1d5f503bd8c1c0...
# 5  702e4598004745673c0f6b50387bef9e1d5f503bd8c1c0...
# 6  702e4598004745673c0f6b50387bef9e1d5f503bd8c1c0...
# 7  702e4598004745673c0f6b50387bef9e1d5f503bd8c1c0...
# 8  702e4598004745673c0f6b50387bef9e1d5f503bd8c1c0...
# 9  702e4598004745673c0f6b50387bef9e1d5f503bd8c1c0...
#
#                                            user_tier  \
# 0  d74a5cebc23c56af60a5768c22d44b52f598629d4011fa...
# 1  d74a5cebc23c56af60a5768c22d44b52f598629d4011fa...
# 2  d74a5cebc23c56af60a5768c22d44b52f598629d4011fa...
# 3  d74a5cebc23c56af60a5768c22d44b52f598629d4011fa...
# 4  d74a5cebc23c56af60a5768c22d44b52f598629d4011fa...
# 5  d74a5cebc23c56af60a5768c22d44b52f598629d4011fa...
# 6  d74a5cebc23c56af60a5768c22d44b52f598629d4011fa...
# 7  d74a5cebc23c56af60a5768c22d44b52f598629d4011fa...
# 8  d74a5cebc23c56af60a5768c22d44b52f598629d4011fa...
# 9  d74a5cebc23c56af60a5768c22d44b52f598629d4011fa...
#
#                                         user_country  ... product_price week  \
# 0  ea2f413bd8fda0b91a814a68aa520044b204796991a343...  ...      0.000466    6
# 1  ea2f413bd8fda0b91a814a68aa520044b204796991a343...  ...      0.001068    6
# 2  ea2f413bd8fda0b91a814a68aa520044b204796991a343...  ...      0.001238    6
# 3  ea2f413bd8fda0b91a814a68aa520044b204796991a343...  ...      0.000465    6
# 4  ea2f413bd8fda0b91a814a68aa520044b204796991a343...  ...      0.000936    6
# 5  ea2f413bd8fda0b91a814a68aa520044b204796991a343...  ...      0.001765    6
# 6  ea2f413bd8fda0b91a814a68aa520044b204796991a343...  ...      0.000804    7
# 7  ea2f413bd8fda0b91a814a68aa520044b204796991a343...  ...      0.000722    7
# 8  ea2f413bd8fda0b91a814a68aa520044b204796991a343...  ...      0.000916    7
# 9  ea2f413bd8fda0b91a814a68aa520044b204796991a343...  ...      0.000761    7
#
#    week_day  is_click  days_elapsed  \
# 0         6         0            41
# 1         6         0            41
# 2         6         1            41
# 3         6         0            41
# 4         6         0            41
# 5         6         0            41
# 6         2         0            44
# 7         2         0            44
# 8         2         1            44
# 9         2         0            44
#
#                                    days_elapsed_list  user_step price_rank  \
# 0                           [41, 41, 41, 41, 41, 41]          3          2
# 1                           [41, 41, 41, 41, 41, 41]          3          4
# 2                           [41, 41, 41, 41, 41, 41]          3          5
# 3                           [41, 41, 41, 41, 41, 41]          3          1
# 4                           [41, 41, 41, 41, 41, 41]          3          3
# 5                           [41, 41, 41, 41, 41, 41]          3          6
# 6  [44, 44, 44, 44, 44, 44, 44, 44, 44, 44, 44, 4...          1          4
# 7  [44, 44, 44, 44, 44, 44, 44, 44, 44, 44, 44, 4...          1          2
# 8  [44, 44, 44, 44, 44, 44, 44, 44, 44, 44, 44, 4...          1          6
# 9  [44, 44, 44, 44, 44, 44, 44, 44, 44, 44, 44, 4...          1          3
#
#    start_online_date  start_online_date_rank
# 0         573.041667                       6
# 1         262.041667                       3
# 2         226.041667                       2
# 3         394.000000                       5
# 4         273.041667                       4
# 5         133.000000                       1
# 6         160.041667                       2
# 7         141.000000                       1
# 8         162.041667                       3
# 9         444.000000                       5
#
# [10 rows x 22 columns]

# %%
query_product_list_train = pd.DataFrame(train.groupby('query_id')['product_id'].apply(list)).reset_index()
query_product_list_train = query_product_list_train.rename(columns={"product_id": "query_product_list"})

query_product_list_val = pd.DataFrame(val.groupby('query_id')['product_id'].apply(list)).reset_index()
query_product_list_val = query_product_list_val.rename(columns={"product_id": "query_product_list"})

query_product_list_test = pd.DataFrame(test.groupby('query_id')['product_id'].apply(list)).reset_index()
query_product_list_test = query_product_list_test.rename(columns={"product_id": "query_product_list"})

query_product_list_train.head()
# Out:
#                                             query_id  \
# 0  0000437da0efd6e292f12a8a3bf7525de5bd05b5807a74...
# 1  00008bcf52759e7e70d533026da637b1cfeb0dc04a67ed...
# 2  000090cdd1f86fbf8bcf0e4d1be90e651a9062082faf38...
# 3  0000ec26db939fbf176f3e7a911a15955f5132018b7344...
# 4  0000f79466baf1fdfcd0f97e32a005e78e0ab0e58a283b...
#
#                                   query_product_list
# 0  [1efd18182268101b62a1ea12a9cafbe05487f3abb9292...
# 1  [b08c37eac9adf04388a290b13105167b4a50911ac14e5...
# 2  [6dccffb4b2db836fc4baf7dafc31f75358891eb153175...
# 3  [dc6bdc843456153ef19830388e9416e281634f07ac67d...
# 4  [5d6cca3626e91e7a812af0c19b6a7c9853ce044720021...

# %%
train = train.merge(query_product_list_train, on='query_id', how='left')
val = val.merge(query_product_list_val, on='query_id', how='left')
test = test.merge(query_product_list_test, on='query_id', how='left')

# %%
train.head()
# Out:
#                                             query_id  \
# 0  0000437da0efd6e292f12a8a3bf7525de5bd05b5807a74...
# 1  0000437da0efd6e292f12a8a3bf7525de5bd05b5807a74...
# 2  0000437da0efd6e292f12a8a3bf7525de5bd05b5807a74...
# 3  0000437da0efd6e292f12a8a3bf7525de5bd05b5807a74...
# 4  0000437da0efd6e292f12a8a3bf7525de5bd05b5807a74...
#
#                                              user_id  \
# 0  ff2088c2fd3bf9cb8c2601252dd65a99201f59972820d3...
# 1  ff2088c2fd3bf9cb8c2601252dd65a99201f59972820d3...
# 2  ff2088c2fd3bf9cb8c2601252dd65a99201f59972820d3...
# 3  ff2088c2fd3bf9cb8c2601252dd65a99201f59972820d3...
# 4  ff2088c2fd3bf9cb8c2601252dd65a99201f59972820d3...
#
#                                           session_id  \
# 0  37b65411191e2f12441edad785c6ae94741eceaffdcb80...
# 1  37b65411191e2f12441edad785c6ae94741eceaffdcb80...
# 2  37b65411191e2f12441edad785c6ae94741eceaffdcb80...
# 3  37b65411191e2f12441edad785c6ae94741eceaffdcb80...
# 4  37b65411191e2f12441edad785c6ae94741eceaffdcb80...
#
#                                           product_id  \
# 0  1efd18182268101b62a1ea12a9cafbe05487f3abb92924...
# 1  62349c6eda0dc9fe8bb023213f03ebe93aefa5cbcdfecf...
# 2  aa0bbdfa55326b5c08d3472b1ee1d56fe13a82f63f46c8...
# 3  793301d78ea43b599acf05d350c8f9e485f5deaa417284...
# 4  9e03ca4af958bef1ce5d54e684a40ee7e3a9aa7e5010b6...
#
#                                            page_type  \
# 0  06a7f8e972f61aeb0e06335699518079a444e4450ff766...
# 1  06a7f8e972f61aeb0e06335699518079a444e4450ff766...
# 2  06a7f8e972f61aeb0e06335699518079a444e4450ff766...
# 3  06a7f8e972f61aeb0e06335699518079a444e4450ff766...
# 4  06a7f8e972f61aeb0e06335699518079a444e4450ff766...
#
#                                   previous_page_type  \
# 0  d05d943023ee7c2091506a72ce25841e84f88a4233a11d...
# 1  d05d943023ee7c2091506a72ce25841e84f88a4233a11d...
# 2  d05d943023ee7c2091506a72ce25841e84f88a4233a11d...
# 3  d05d943023ee7c2091506a72ce25841e84f88a4233a11d...
# 4  d05d943023ee7c2091506a72ce25841e84f88a4233a11d...
#
#                                      device_category  \
# 0  bf2241c08d92d32a6782b4041a2c11ca58882ca88454b3...
# 1  bf2241c08d92d32a6782b4041a2c11ca58882ca88454b3...
# 2  bf2241c08d92d32a6782b4041a2c11ca58882ca88454b3...
# 3  bf2241c08d92d32a6782b4041a2c11ca58882ca88454b3...
# 4  bf2241c08d92d32a6782b4041a2c11ca58882ca88454b3...
#
#                                      device_platform  \
# 0  702e4598004745673c0f6b50387bef9e1d5f503bd8c1c0...
# 1  702e4598004745673c0f6b50387bef9e1d5f503bd8c1c0...
# 2  702e4598004745673c0f6b50387bef9e1d5f503bd8c1c0...
# 3  702e4598004745673c0f6b50387bef9e1d5f503bd8c1c0...
# 4  702e4598004745673c0f6b50387bef9e1d5f503bd8c1c0...
#
#                                            user_tier  \
# 0  d74a5cebc23c56af60a5768c22d44b52f598629d4011fa...
# 1  d74a5cebc23c56af60a5768c22d44b52f598629d4011fa...
# 2  d74a5cebc23c56af60a5768c22d44b52f598629d4011fa...
# 3  d74a5cebc23c56af60a5768c22d44b52f598629d4011fa...
# 4  d74a5cebc23c56af60a5768c22d44b52f598629d4011fa...
#
#                                         user_country  ... week week_day  \
# 0  ea2f413bd8fda0b91a814a68aa520044b204796991a343...  ...    6        6
# 1  ea2f413bd8fda0b91a814a68aa520044b204796991a343...  ...    6        6
# 2  ea2f413bd8fda0b91a814a68aa520044b204796991a343...  ...    6        6
# 3  ea2f413bd8fda0b91a814a68aa520044b204796991a343...  ...    6        6
# 4  ea2f413bd8fda0b91a814a68aa520044b204796991a343...  ...    6        6
#
#    is_click  days_elapsed         days_elapsed_list  user_step  price_rank  \
# 0         0            41  [41, 41, 41, 41, 41, 41]          3           2
# 1         0            41  [41, 41, 41, 41, 41, 41]          3           4
# 2         1            41  [41, 41, 41, 41, 41, 41]          3           5
# 3         0            41  [41, 41, 41, 41, 41, 41]          3           1
# 4         0            41  [41, 41, 41, 41, 41, 41]          3           3
#
#   start_online_date  start_online_date_rank  \
# 0        573.041667                       6
# 1        262.041667                       3
# 2        226.041667                       2
# 3        394.000000                       5
# 4        273.041667                       4
#
#                                   query_product_list
# 0  [1efd18182268101b62a1ea12a9cafbe05487f3abb9292...
# 1  [1efd18182268101b62a1ea12a9cafbe05487f3abb9292...
# 2  [1efd18182268101b62a1ea12a9cafbe05487f3abb9292...
# 3  [1efd18182268101b62a1ea12a9cafbe05487f3abb9292...
# 4  [1efd18182268101b62a1ea12a9cafbe05487f3abb9292...
#
# [5 rows x 23 columns]

# %%
val.head()
# Out:
#                                             query_id  \
# 0  00004e487e05ff29ac41a930f9ed972fe4cbf6a7a17794...
# 1  00004e487e05ff29ac41a930f9ed972fe4cbf6a7a17794...
# 2  00004e487e05ff29ac41a930f9ed972fe4cbf6a7a17794...
# 3  00004e487e05ff29ac41a930f9ed972fe4cbf6a7a17794...
# 4  00004e487e05ff29ac41a930f9ed972fe4cbf6a7a17794...
#
#                                              user_id  \
# 0  7cd797f1f55010930dd801512ba5e74216f3b030f507f8...
# 1  7cd797f1f55010930dd801512ba5e74216f3b030f507f8...
# 2  7cd797f1f55010930dd801512ba5e74216f3b030f507f8...
# 3  7cd797f1f55010930dd801512ba5e74216f3b030f507f8...
# 4  7cd797f1f55010930dd801512ba5e74216f3b030f507f8...
#
#                                           session_id  \
# 0  c5e8a7671218a373618768419a0872774145e1a1d5bf78...
# 1  c5e8a7671218a373618768419a0872774145e1a1d5bf78...
# 2  c5e8a7671218a373618768419a0872774145e1a1d5bf78...
# 3  c5e8a7671218a373618768419a0872774145e1a1d5bf78...
# 4  c5e8a7671218a373618768419a0872774145e1a1d5bf78...
#
#                                           product_id  \
# 0  d8a205200d4c2151fd2cf070ff7f44999d7a184faad30f...
# 1  3d7014b28491366ce149339689c90331bd2c42e251713a...
# 2  5ac7d91135ed2a6d44ec48ec586ceacbab3fc67d4bf319...
# 3  998800d85572455b61c0e3eea04141a09e8793893aec9c...
# 4  1455bc965260200d68107d43cf6282cbae75de2072a4aa...
#
#                                            page_type  \
# 0  06a7f8e972f61aeb0e06335699518079a444e4450ff766...
# 1  06a7f8e972f61aeb0e06335699518079a444e4450ff766...
# 2  06a7f8e972f61aeb0e06335699518079a444e4450ff766...
# 3  06a7f8e972f61aeb0e06335699518079a444e4450ff766...
# 4  06a7f8e972f61aeb0e06335699518079a444e4450ff766...
#
#                                   previous_page_type  \
# 0  d74a5cebc23c56af60a5768c22d44b52f598629d4011fa...
# 1  d74a5cebc23c56af60a5768c22d44b52f598629d4011fa...
# 2  d74a5cebc23c56af60a5768c22d44b52f598629d4011fa...
# 3  d74a5cebc23c56af60a5768c22d44b52f598629d4011fa...
# 4  d74a5cebc23c56af60a5768c22d44b52f598629d4011fa...
#
#                                      device_category  \
# 0  bf2241c08d92d32a6782b4041a2c11ca58882ca88454b3...
# 1  bf2241c08d92d32a6782b4041a2c11ca58882ca88454b3...
# 2  bf2241c08d92d32a6782b4041a2c11ca58882ca88454b3...
# 3  bf2241c08d92d32a6782b4041a2c11ca58882ca88454b3...
# 4  bf2241c08d92d32a6782b4041a2c11ca58882ca88454b3...
#
#                                      device_platform  \
# 0  702e4598004745673c0f6b50387bef9e1d5f503bd8c1c0...
# 1  702e4598004745673c0f6b50387bef9e1d5f503bd8c1c0...
# 2  702e4598004745673c0f6b50387bef9e1d5f503bd8c1c0...
# 3  702e4598004745673c0f6b50387bef9e1d5f503bd8c1c0...
# 4  702e4598004745673c0f6b50387bef9e1d5f503bd8c1c0...
#
#                                            user_tier  \
# 0  d74a5cebc23c56af60a5768c22d44b52f598629d4011fa...
# 1  d74a5cebc23c56af60a5768c22d44b52f598629d4011fa...
# 2  d74a5cebc23c56af60a5768c22d44b52f598629d4011fa...
# 3  d74a5cebc23c56af60a5768c22d44b52f598629d4011fa...
# 4  d74a5cebc23c56af60a5768c22d44b52f598629d4011fa...
#
#                                         user_country  ...  \
# 0  95d5a1bd42a07143383299c081524278a16ef5ce55507c...  ...
# 1  95d5a1bd42a07143383299c081524278a16ef5ce55507c...  ...
# 2  95d5a1bd42a07143383299c081524278a16ef5ce55507c...  ...
# 3  95d5a1bd42a07143383299c081524278a16ef5ce55507c...  ...
# 4  95d5a1bd42a07143383299c081524278a16ef5ce55507c...  ...
#
#                                        context_value product_price  week  \
# 0  ec8ebb5a4319e2a526e3e6ab6e64830e8c2aa1fb20ecb2...      0.000142     7
# 1  ec8ebb5a4319e2a526e3e6ab6e64830e8c2aa1fb20ecb2...      0.000877     7
# 2  ec8ebb5a4319e2a526e3e6ab6e64830e8c2aa1fb20ecb2...      0.000110     7
# 3  ec8ebb5a4319e2a526e3e6ab6e64830e8c2aa1fb20ecb2...      0.000941     7
# 4  ec8ebb5a4319e2a526e3e6ab6e64830e8c2aa1fb20ecb2...      0.000142     7
#
#    week_day  days_elapsed  user_step  price_rank  start_online_date  \
# 0         4            46          1           3         402.000000
# 1         4            46          1           4        1393.041667
# 2         4            46          1           1         482.000000
# 3         4            46          1           5         217.041667
# 4         4            46          1           3         384.000000
#
#    start_online_date_rank                                 query_product_list
# 0                       3  [d8a205200d4c2151fd2cf070ff7f44999d7a184faad30...
# 1                       6  [d8a205200d4c2151fd2cf070ff7f44999d7a184faad30...
# 2                       5  [d8a205200d4c2151fd2cf070ff7f44999d7a184faad30...
# 3                       1  [d8a205200d4c2151fd2cf070ff7f44999d7a184faad30...
# 4                       2  [d8a205200d4c2151fd2cf070ff7f44999d7a184faad30...
#
# [5 rows x 21 columns]

# %%
train = train.drop(["days_elapsed_list"], 1)

# %%
train.head(2)
# Out:
#                                             query_id  \
# 0  0000437da0efd6e292f12a8a3bf7525de5bd05b5807a74...
# 1  0000437da0efd6e292f12a8a3bf7525de5bd05b5807a74...
#
#                                              user_id  \
# 0  ff2088c2fd3bf9cb8c2601252dd65a99201f59972820d3...
# 1  ff2088c2fd3bf9cb8c2601252dd65a99201f59972820d3...
#
#                                           session_id  \
# 0  37b65411191e2f12441edad785c6ae94741eceaffdcb80...
# 1  37b65411191e2f12441edad785c6ae94741eceaffdcb80...
#
#                                           product_id  \
# 0  1efd18182268101b62a1ea12a9cafbe05487f3abb92924...
# 1  62349c6eda0dc9fe8bb023213f03ebe93aefa5cbcdfecf...
#
#                                            page_type  \
# 0  06a7f8e972f61aeb0e06335699518079a444e4450ff766...
# 1  06a7f8e972f61aeb0e06335699518079a444e4450ff766...
#
#                                   previous_page_type  \
# 0  d05d943023ee7c2091506a72ce25841e84f88a4233a11d...
# 1  d05d943023ee7c2091506a72ce25841e84f88a4233a11d...
#
#                                      device_category  \
# 0  bf2241c08d92d32a6782b4041a2c11ca58882ca88454b3...
# 1  bf2241c08d92d32a6782b4041a2c11ca58882ca88454b3...
#
#                                      device_platform  \
# 0  702e4598004745673c0f6b50387bef9e1d5f503bd8c1c0...
# 1  702e4598004745673c0f6b50387bef9e1d5f503bd8c1c0...
#
#                                            user_tier  \
# 0  d74a5cebc23c56af60a5768c22d44b52f598629d4011fa...
# 1  d74a5cebc23c56af60a5768c22d44b52f598629d4011fa...
#
#                                         user_country  ... product_price week  \
# 0  ea2f413bd8fda0b91a814a68aa520044b204796991a343...  ...      0.000466    6
# 1  ea2f413bd8fda0b91a814a68aa520044b204796991a343...  ...      0.001068    6
#
#    week_day  is_click  days_elapsed  user_step  price_rank  start_online_date  \
# 0         6         0            41          3           2         573.041667
# 1         6         0            41          3           4         262.041667
#
#    start_online_date_rank                                 query_product_list
# 0                       6  [1efd18182268101b62a1ea12a9cafbe05487f3abb9292...
# 1                       3  [1efd18182268101b62a1ea12a9cafbe05487f3abb9292...
#
# [2 rows x 22 columns]

# %%
# train.to_csv("../preprocessed_data/rank_features/train_rank_features_and_query_prod_list", index=False)
# val.to_csv("../preprocessed_data/rank_features/val_rank_features_and_query_prod_list", index=False)
# test.to_csv("../preprocessed_data/rank_features/test_rank_features_and_query_prod_list.csv", index=False)

# %%
train.iloc[20, :]['query_id']
# Out:
# '0000ec26db939fbf176f3e7a911a15955f5132018b7344999a3656d53416d2f5'

# %%
pd.options.display.max_rows = None
pd.options.display.max_columns = None

# %%
train[train['query_id']=='0000ec26db939fbf176f3e7a911a15955f5132018b7344999a3656d53416d2f5']
# Out:
#                                              query_id  \
# 18  0000ec26db939fbf176f3e7a911a15955f5132018b7344...
# 19  0000ec26db939fbf176f3e7a911a15955f5132018b7344...
# 20  0000ec26db939fbf176f3e7a911a15955f5132018b7344...
# 21  0000ec26db939fbf176f3e7a911a15955f5132018b7344...
# 22  0000ec26db939fbf176f3e7a911a15955f5132018b7344...
# 23  0000ec26db939fbf176f3e7a911a15955f5132018b7344...
#
#                                               user_id  \
# 18  c987ad8de6e627726dde606f0857a4c9ee9d3b88db5516...
# 19  c987ad8de6e627726dde606f0857a4c9ee9d3b88db5516...
# 20  c987ad8de6e627726dde606f0857a4c9ee9d3b88db5516...
# 21  c987ad8de6e627726dde606f0857a4c9ee9d3b88db5516...
# 22  c987ad8de6e627726dde606f0857a4c9ee9d3b88db5516...
# 23  c987ad8de6e627726dde606f0857a4c9ee9d3b88db5516...
#
#                                            session_id  \
# 18  5a00f99a039837124d25f1e103e240597bd047d9337fad...
# 19  5a00f99a039837124d25f1e103e240597bd047d9337fad...
# 20  5a00f99a039837124d25f1e103e240597bd047d9337fad...
# 21  5a00f99a039837124d25f1e103e240597bd047d9337fad...
# 22  5a00f99a039837124d25f1e103e240597bd047d9337fad...
# 23  5a00f99a039837124d25f1e103e240597bd047d9337fad...
#
#                                            product_id  \
# 18  dc6bdc843456153ef19830388e9416e281634f07ac67df...
# 19  0f8dd9cec7116dc003af9a905c35f17addf26e136024e8...
# 20  96520f9d09bf9354cc54a2f27927ebb2a16aa3005f673d...
# 21  aad68142b7cf2c0e043d94131062277df66b7556e70cb6...
# 22  b649308564db159ad3d7baf7074534b4b74ca135cee3a8...
# 23  3ec05d5155c1da748d925f4f29e1174d0f1667e0848cc2...
#
#                                             page_type  \
# 18  06a7f8e972f61aeb0e06335699518079a444e4450ff766...
# 19  06a7f8e972f61aeb0e06335699518079a444e4450ff766...
# 20  06a7f8e972f61aeb0e06335699518079a444e4450ff766...
# 21  06a7f8e972f61aeb0e06335699518079a444e4450ff766...
# 22  06a7f8e972f61aeb0e06335699518079a444e4450ff766...
# 23  06a7f8e972f61aeb0e06335699518079a444e4450ff766...
#
#                                    previous_page_type  \
# 18  d74a5cebc23c56af60a5768c22d44b52f598629d4011fa...
# 19  d74a5cebc23c56af60a5768c22d44b52f598629d4011fa...
# 20  d74a5cebc23c56af60a5768c22d44b52f598629d4011fa...
# 21  d74a5cebc23c56af60a5768c22d44b52f598629d4011fa...
# 22  d74a5cebc23c56af60a5768c22d44b52f598629d4011fa...
# 23  d74a5cebc23c56af60a5768c22d44b52f598629d4011fa...
#
#                                       device_category  \
# 18  d6538f13ace825448d0af4fa5e58d2d08fa2d0850e5e14...
# 19  d6538f13ace825448d0af4fa5e58d2d08fa2d0850e5e14...
# 20  d6538f13ace825448d0af4fa5e58d2d08fa2d0850e5e14...
# 21  d6538f13ace825448d0af4fa5e58d2d08fa2d0850e5e14...
# 22  d6538f13ace825448d0af4fa5e58d2d08fa2d0850e5e14...
# 23  d6538f13ace825448d0af4fa5e58d2d08fa2d0850e5e14...
#
#                                       device_platform  \
# 18  d6538f13ace825448d0af4fa5e58d2d08fa2d0850e5e14...
# 19  d6538f13ace825448d0af4fa5e58d2d08fa2d0850e5e14...
# 20  d6538f13ace825448d0af4fa5e58d2d08fa2d0850e5e14...
# 21  d6538f13ace825448d0af4fa5e58d2d08fa2d0850e5e14...
# 22  d6538f13ace825448d0af4fa5e58d2d08fa2d0850e5e14...
# 23  d6538f13ace825448d0af4fa5e58d2d08fa2d0850e5e14...
#
#                                             user_tier  \
# 18  d74a5cebc23c56af60a5768c22d44b52f598629d4011fa...
# 19  d74a5cebc23c56af60a5768c22d44b52f598629d4011fa...
# 20  d74a5cebc23c56af60a5768c22d44b52f598629d4011fa...
# 21  d74a5cebc23c56af60a5768c22d44b52f598629d4011fa...
# 22  d74a5cebc23c56af60a5768c22d44b52f598629d4011fa...
# 23  d74a5cebc23c56af60a5768c22d44b52f598629d4011fa...
#
#                                          user_country context_type  \
# 18  fec032cb05435471f2305006f4a1ba994c9d2f4bcad8ef...   product_id
# 19  fec032cb05435471f2305006f4a1ba994c9d2f4bcad8ef...   product_id
# 20  fec032cb05435471f2305006f4a1ba994c9d2f4bcad8ef...   product_id
# 21  fec032cb05435471f2305006f4a1ba994c9d2f4bcad8ef...   product_id
# 22  fec032cb05435471f2305006f4a1ba994c9d2f4bcad8ef...   product_id
# 23  fec032cb05435471f2305006f4a1ba994c9d2f4bcad8ef...   product_id
#
#                                         context_value  product_price  week  \
# 18  8c3fae5b2aa97a3dc46de03d4e664b9df1d73642fe61f8...       0.001682     5
# 19  8c3fae5b2aa97a3dc46de03d4e664b9df1d73642fe61f8...       0.001948     5
# 20  8c3fae5b2aa97a3dc46de03d4e664b9df1d73642fe61f8...       0.001743     5
# 21  8c3fae5b2aa97a3dc46de03d4e664b9df1d73642fe61f8...       0.000611     5
# 22  8c3fae5b2aa97a3dc46de03d4e664b9df1d73642fe61f8...       0.003332     5
# 23  8c3fae5b2aa97a3dc46de03d4e664b9df1d73642fe61f8...       0.001531     5
#
#     week_day  is_click  days_elapsed  price_rank  start_online_date  \
# 18         1         0            29           3         504.000000
# 19         1         0            29           5         812.000000
# 20         1         0            29           4         227.041667
# 21         1         0            29           1         161.041667
# 22         1         0            29           6         188.041667
# 23         1         1            29           2         475.000000
#
#     start_online_date_rank                                 query_product_list  \
# 18                       5  [dc6bdc843456153ef19830388e9416e281634f07ac67d...
# 19                       6  [dc6bdc843456153ef19830388e9416e281634f07ac67d...
# 20                       3  [dc6bdc843456153ef19830388e9416e281634f07ac67d...
# 21                       1  [dc6bdc843456153ef19830388e9416e281634f07ac67d...
# 22                       2  [dc6bdc843456153ef19830388e9416e281634f07ac67d...
# 23                       4  [dc6bdc843456153ef19830388e9416e281634f07ac67d...
#
#     user_step
# 18          1
# 19          1
# 20          1
# 21          1
# 22          1
# 23          1

# %%
train[train['query_id']=='0000ec26db939fbf176f3e7a911a15955f5132018b7344999a3656d53416d2f5']['context_value'].unique().tolist()
# Out:
# ['8c3fae5b2aa97a3dc46de03d4e664b9df1d73642fe61f88f076eb90cd39a7d40']

# %%
train[train['query_id']=='0000ec26db939fbf176f3e7a911a15955f5132018b7344999a3656d53416d2f5']['user_id'].unique().tolist(),\
train[train['query_id']=='0000ec26db939fbf176f3e7a911a15955f5132018b7344999a3656d53416d2f5']['session_id'].unique().tolist()
# Out:
# (['c987ad8de6e627726dde606f0857a4c9ee9d3b88db55165d320b883c6bfd4795'],
#  ['5a00f99a039837124d25f1e103e240597bd047d9337fad83a301d59abf765134'])

# %%
train[train['query_id']=='0000ec26db939fbf176f3e7a911a15955f5132018b7344999a3656d53416d2f5']['product_id'].unique().tolist()
# Out:
# ['dc6bdc843456153ef19830388e9416e281634f07ac67dfe642d84618f3e7feae',
#  '0f8dd9cec7116dc003af9a905c35f17addf26e136024e8c672076257031f3d10',
#  '96520f9d09bf9354cc54a2f27927ebb2a16aa3005f673d8cd0eef92cf0f0b9d0',
#  'aad68142b7cf2c0e043d94131062277df66b7556e70cb668a7e306edf0bb11ac',
#  'b649308564db159ad3d7baf7074534b4b74ca135cee3a85b21950356121a0d0f',
#  '3ec05d5155c1da748d925f4f29e1174d0f1667e0848cc2653742cbcd55447239']

# %%
train[(train['user_id']=='c987ad8de6e627726dde606f0857a4c9ee9d3b88db55165d320b883c6bfd4795') & (train['session_id']=='5a00f99a039837124d25f1e103e240597bd047d9337fad83a301d59abf765134')]
# Out:
#                                              query_id  \
# 18  0000ec26db939fbf176f3e7a911a15955f5132018b7344...
# 19  0000ec26db939fbf176f3e7a911a15955f5132018b7344...
# 20  0000ec26db939fbf176f3e7a911a15955f5132018b7344...
# 21  0000ec26db939fbf176f3e7a911a15955f5132018b7344...
# 22  0000ec26db939fbf176f3e7a911a15955f5132018b7344...
# 23  0000ec26db939fbf176f3e7a911a15955f5132018b7344...
#
#                                               user_id  \
# 18  c987ad8de6e627726dde606f0857a4c9ee9d3b88db5516...
# 19  c987ad8de6e627726dde606f0857a4c9ee9d3b88db5516...
# 20  c987ad8de6e627726dde606f0857a4c9ee9d3b88db5516...
# 21  c987ad8de6e627726dde606f0857a4c9ee9d3b88db5516...
# 22  c987ad8de6e627726dde606f0857a4c9ee9d3b88db5516...
# 23  c987ad8de6e627726dde606f0857a4c9ee9d3b88db5516...
#
#                                            session_id  \
# 18  5a00f99a039837124d25f1e103e240597bd047d9337fad...
# 19  5a00f99a039837124d25f1e103e240597bd047d9337fad...
# 20  5a00f99a039837124d25f1e103e240597bd047d9337fad...
# 21  5a00f99a039837124d25f1e103e240597bd047d9337fad...
# 22  5a00f99a039837124d25f1e103e240597bd047d9337fad...
# 23  5a00f99a039837124d25f1e103e240597bd047d9337fad...
#
#                                            product_id  \
# 18  dc6bdc843456153ef19830388e9416e281634f07ac67df...
# 19  0f8dd9cec7116dc003af9a905c35f17addf26e136024e8...
# 20  96520f9d09bf9354cc54a2f27927ebb2a16aa3005f673d...
# 21  aad68142b7cf2c0e043d94131062277df66b7556e70cb6...
# 22  b649308564db159ad3d7baf7074534b4b74ca135cee3a8...
# 23  3ec05d5155c1da748d925f4f29e1174d0f1667e0848cc2...
#
#                                             page_type  \
# 18  06a7f8e972f61aeb0e06335699518079a444e4450ff766...
# 19  06a7f8e972f61aeb0e06335699518079a444e4450ff766...
# 20  06a7f8e972f61aeb0e06335699518079a444e4450ff766...
# 21  06a7f8e972f61aeb0e06335699518079a444e4450ff766...
# 22  06a7f8e972f61aeb0e06335699518079a444e4450ff766...
# 23  06a7f8e972f61aeb0e06335699518079a444e4450ff766...
#
#                                    previous_page_type  \
# 18  d74a5cebc23c56af60a5768c22d44b52f598629d4011fa...
# 19  d74a5cebc23c56af60a5768c22d44b52f598629d4011fa...
# 20  d74a5cebc23c56af60a5768c22d44b52f598629d4011fa...
# 21  d74a5cebc23c56af60a5768c22d44b52f598629d4011fa...
# 22  d74a5cebc23c56af60a5768c22d44b52f598629d4011fa...
# 23  d74a5cebc23c56af60a5768c22d44b52f598629d4011fa...
#
#                                       device_category  \
# 18  d6538f13ace825448d0af4fa5e58d2d08fa2d0850e5e14...
# 19  d6538f13ace825448d0af4fa5e58d2d08fa2d0850e5e14...
# 20  d6538f13ace825448d0af4fa5e58d2d08fa2d0850e5e14...
# 21  d6538f13ace825448d0af4fa5e58d2d08fa2d0850e5e14...
# 22  d6538f13ace825448d0af4fa5e58d2d08fa2d0850e5e14...
# 23  d6538f13ace825448d0af4fa5e58d2d08fa2d0850e5e14...
#
#                                       device_platform  \
# 18  d6538f13ace825448d0af4fa5e58d2d08fa2d0850e5e14...
# 19  d6538f13ace825448d0af4fa5e58d2d08fa2d0850e5e14...
# 20  d6538f13ace825448d0af4fa5e58d2d08fa2d0850e5e14...
# 21  d6538f13ace825448d0af4fa5e58d2d08fa2d0850e5e14...
# 22  d6538f13ace825448d0af4fa5e58d2d08fa2d0850e5e14...
# 23  d6538f13ace825448d0af4fa5e58d2d08fa2d0850e5e14...
#
#                                             user_tier  \
# 18  d74a5cebc23c56af60a5768c22d44b52f598629d4011fa...
# 19  d74a5cebc23c56af60a5768c22d44b52f598629d4011fa...
# 20  d74a5cebc23c56af60a5768c22d44b52f598629d4011fa...
# 21  d74a5cebc23c56af60a5768c22d44b52f598629d4011fa...
# 22  d74a5cebc23c56af60a5768c22d44b52f598629d4011fa...
# 23  d74a5cebc23c56af60a5768c22d44b52f598629d4011fa...
#
#                                          user_country context_type  \
# 18  fec032cb05435471f2305006f4a1ba994c9d2f4bcad8ef...   product_id
# 19  fec032cb05435471f2305006f4a1ba994c9d2f4bcad8ef...   product_id
# 20  fec032cb05435471f2305006f4a1ba994c9d2f4bcad8ef...   product_id
# 21  fec032cb05435471f2305006f4a1ba994c9d2f4bcad8ef...   product_id
# 22  fec032cb05435471f2305006f4a1ba994c9d2f4bcad8ef...   product_id
# 23  fec032cb05435471f2305006f4a1ba994c9d2f4bcad8ef...   product_id
#
#                                         context_value  product_price  week  \
# 18  8c3fae5b2aa97a3dc46de03d4e664b9df1d73642fe61f8...       0.001682     5
# 19  8c3fae5b2aa97a3dc46de03d4e664b9df1d73642fe61f8...       0.001948     5
# 20  8c3fae5b2aa97a3dc46de03d4e664b9df1d73642fe61f8...       0.001743     5
# 21  8c3fae5b2aa97a3dc46de03d4e664b9df1d73642fe61f8...       0.000611     5
# 22  8c3fae5b2aa97a3dc46de03d4e664b9df1d73642fe61f8...       0.003332     5
# 23  8c3fae5b2aa97a3dc46de03d4e664b9df1d73642fe61f8...       0.001531     5
#
#     week_day  is_click  days_elapsed  price_rank  start_online_date  \
# 18         1         0            29           3         504.000000
# 19         1         0            29           5         812.000000
# 20         1         0            29           4         227.041667
# 21         1         0            29           1         161.041667
# 22         1         0            29           6         188.041667
# 23         1         1            29           2         475.000000
#
#     start_online_date_rank                                 query_product_list  \
# 18                       5  [dc6bdc843456153ef19830388e9416e281634f07ac67d...
# 19                       6  [dc6bdc843456153ef19830388e9416e281634f07ac67d...
# 20                       3  [dc6bdc843456153ef19830388e9416e281634f07ac67d...
# 21                       1  [dc6bdc843456153ef19830388e9416e281634f07ac67d...
# 22                       2  [dc6bdc843456153ef19830388e9416e281634f07ac67d...
# 23                       4  [dc6bdc843456153ef19830388e9416e281634f07ac67d...
#
#     user_step
# 18          1
# 19          1
# 20          1
# 21          1
# 22          1
# 23          1

# %%
attributes_df.head(2)
# Out:
#                                           product_id  \
# 0  0013f07ccdf212210c110e63f0de46e37669c17a4d855a...
# 1  002239cd57f19f22e557030dff363dfbd1344d8f7ac829...
#
#                                               gender  \
# 0  a8c9cca4c116691f1e331a5058e84f05e31696bc4f611c...
# 1  4a00d8b84bdb2ec2f219304d3883a46336f9fb38d2f1e6...
#
#                                          main_colour  \
# 0  7673fc4fdc325f3785a223787d2b32e381e8b4c1c8a765...
# 1  0f97dafafa5dc4bb18853ea00776dfcc52302f40411b50...
#
#                                        second_colour  \
# 0  4737cd35940c2338e96c18a25aeb6848d46f0da795bce8...
# 1  ca8c396e7422e324d4454a911e0319d07b85a4fb89b006...
#
#                                               season  \
# 0  847a067597e39838f1f85b0774f44e68b4d6e64d3ec4dd...
# 1  9db35d237f5873f0410d3ca18c07430270086eb1e7838d...
#
#                                           collection  \
# 0  a3791e8d85c005b0d9d60d6d3b7e8edd2f256a5cc928d0...
# 1  a3791e8d85c005b0d9d60d6d3b7e8edd2f256a5cc928d0...
#
#                                       category_id_l1  \
# 0  abf367e49718254e068eee51a565fdcede2d741e4c7e33...
# 1  e54f8513b708db3afdbd4950bd3420579a8cddabf4c1b3...
#
#                                       category_id_l2  \
# 0  61fe255948ec07c4eb25c70f7144b54beddd00466ad866...
# 1  3809cade495cd7dc289e6aee521d380549ebd3456f03bc...
#
#                                       category_id_l3  \
# 0  05f872d8b8ec85642ad49786d6e443c0df6e7df4bdcba3...
# 1  fd021cd2dbaf0d7b6105a1b136cf5a094e025010a2096f...
#
#                                             brand_id  \
# 0  dd6ea8954a945ef0889f30d57b7fdb8d6aaad397e6c6ff...
# 1  a6536c6bc250d525ccd3b63a3ec483a33a2010422932a3...
#
#                                          season_year  start_online_date  \
# 0  c7c4ac6af030e54d02b9e4545e4223e76515c3ce4e498e...        1067.041667
# 1  ef7d8d2e02aec8c328dafde95486f7181c37d07be3d167...         215.041667
#
#                                      material_values  \
# 0  f61ecea9b45f1590e57706b88207449bdd4cb703b917ad...
# 1  1675f293342bbb518ba3a5ad39399aa0a13580653d253e...
#
#                                     attribute_values
# 0  8b45c5d5e010acf257787f2ce0c505857d94709c436991...
# 1  ca8c396e7422e324d4454a911e0319d07b85a4fb89b006...

# %%
attributes_df[attributes_df['product_id']=='8c3fae5b2aa97a3dc46de03d4e664b9df1d73642fe61f88f076eb90cd39a7d40']
# Out:
#                                                product_id  \
# 123979  8c3fae5b2aa97a3dc46de03d4e664b9df1d73642fe61f8...
#
#                                                    gender  \
# 123979  51783ef49eeaae84ab72114d1b79f671847df95b30c8e9...
#
#                                               main_colour  \
# 123979  f67dfa4e29116c5e9f22409d833124c101ec33c7bcfee2...
#
#                                             second_colour  \
# 123979  ca8c396e7422e324d4454a911e0319d07b85a4fb89b006...
#
#                                                    season  \
# 123979  9db35d237f5873f0410d3ca18c07430270086eb1e7838d...
#
#                                                collection  \
# 123979  a3791e8d85c005b0d9d60d6d3b7e8edd2f256a5cc928d0...
#
#                                            category_id_l1  \
# 123979  e10ca949bbdfcd8015a769a7c38f40cbb81d5c45c2fa44...
#
#                                            category_id_l2  \
# 123979  06cf40834ba34f76e8646da4ea12746db8bb55a6034a1b...
#
#                                            category_id_l3  \
# 123979  79728d9f52f11d76cac4400aa475da434dbe61db18dea2...
#
#                                                  brand_id  \
# 123979  67559eed90924e393042d1c369421a30f6153a13498e97...
#
#                                               season_year  start_online_date  \
# 123979  dc1194ba428d5cd4c49f8a769a6577ac1042162da38bc1...         591.041667
#
#                                           material_values  \
# 123979  f61ecea9b45f1590e57706b88207449bdd4cb703b917ad...
#
#                                          attribute_values
# 123979  b47aef240e92e5e272da1197f67988f84996ed71d88a64...

# %%
attributes_df[attributes_df['product_id']=='3ec05d5155c1da748d925f4f29e1174d0f1667e0848cc2653742cbcd55447239']
# Out:
#                                                product_id  \
# 166949  3ec05d5155c1da748d925f4f29e1174d0f1667e0848cc2...
#
#                                                    gender  \
# 166949  51783ef49eeaae84ab72114d1b79f671847df95b30c8e9...
#
#                                               main_colour  \
# 166949  d3034459d822bd39679db3dbc674a30d0d64ba82f24ad4...
#
#                                             second_colour  \
# 166949  4737cd35940c2338e96c18a25aeb6848d46f0da795bce8...
#
#                                                    season  \
# 166949  9db35d237f5873f0410d3ca18c07430270086eb1e7838d...
#
#                                                collection  \
# 166949  4c8006c7e513057a9138641abc2a9e65f4b014a8045259...
#
#                                            category_id_l1  \
# 166949  e10ca949bbdfcd8015a769a7c38f40cbb81d5c45c2fa44...
#
#                                            category_id_l2  \
# 166949  06cf40834ba34f76e8646da4ea12746db8bb55a6034a1b...
#
#                                            category_id_l3  \
# 166949  2486e029ff5a46ab15378f3e53c864cf10fcb705c71fe2...
#
#                                                  brand_id  \
# 166949  4e0cd5da8208d52dbb79be3fab691af569e8f26bf8a06c...
#
#                                               season_year  start_online_date  \
# 166949  dc1194ba428d5cd4c49f8a769a6577ac1042162da38bc1...              475.0
#
#                                           material_values  \
# 166949  a0c383e8931a3908c348b1e7e3d7be3f85fd9d4f615eef...
#
#                                          attribute_values
# 166949  b47aef240e92e5e272da1197f67988f84996ed71d88a64...
